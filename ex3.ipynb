# %%
from datasets import load_dataset, DatasetDict

# %%
dataset = load_dataset("news_commentary", 'de-en')
# Out:
# Found cached dataset news_commentary (/Users/gcm/.cache/huggingface/datasets/news_commentary/de-en/11.0.0/cfab724ce975dc2da51cdae45302389860badc88b74db8570d561ced6004f8b4)
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'translation'],
#         num_rows: 223153
#     })
# })

# %%
dataset['train'][1]
# Out:
# {'id': '1',
#  'translation': {'de': 'SAN FRANCISCO – Es war noch nie leicht, ein rationales Gespräch über den Wert von Gold zu führen.',
#   'en': 'SAN FRANCISCO – It has never been easy to have a rational conversation about the value of gold.'}}

# %%
dataset['train'][1]['translation']
# Out:
# {'de': 'SAN FRANCISCO – Es war noch nie leicht, ein rationales Gespräch über den Wert von Gold zu führen.',
#  'en': 'SAN FRANCISCO – It has never been easy to have a rational conversation about the value of gold.'}

# %%
len(dataset['train'])
# Out:
# 223153

# %%
# function to normalise my text
import unicodedata
import re

# From https://pytorch.org/tutorials/intermediate/seq2seq_translation_tutorial.html
def _normalize(s):
	s = unicodeToAscii(s.lower().strip())
	s = re.sub(r"([.!?])", r" \1", s)
	s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
	return s

#Turn a Unicode string to plain ASCII, thanks to
# https://stackoverflow.com/a/518232/2809427
def unicodeToAscii(s):
	return ''.join(
		c for c in unicodedata.normalize('NFD', s)
		if unicodedata.category(c) != 'Mn'
	)

# %%
# normalise text and save it in variable "data_norm"
MAX_WORDS = 12
data_norm  = []
count = 0
for i in range(len(dataset['train'])):
	en = _normalize(dataset['train'][i]['translation']['en'])
	de = _normalize(dataset['train'][i]['translation']['de'])
	if len(en.split()) <= MAX_WORDS and len(de.split()) <= MAX_WORDS:
		data_norm.append({'idx': count,
						 'en_text': en,
						 'de_text': de,
						 'en_word_idx': [],
						 'de_word_idx': []})
		count = count + 1

# %%
data_norm[:5]
# Out:
# [{'idx': 0,
#   'en_text': ' gold ?',
#   'de_text': 'steigt gold auf . dollar ?',
#   'en_word_idx': [],
#   'de_word_idx': []},
#  {'idx': 1,
#   'en_text': 'wouldn t you know it ?',
#   'de_text': 'und es kam wie es kommen musste .',
#   'en_word_idx': [],
#   'de_word_idx': []},
#  {'idx': 2,
#   'en_text': 'gold prices even hit a record high recently .',
#   'de_text': 'jungst erreichte er sogar ein rekordhoch von . dollar .',
#   'en_word_idx': [],
#   'de_word_idx': []},
#  {'idx': 3,
#   'en_text': 'since then the index has climbed above .',
#   'de_text': 'seit damals ist er auf uber . punkte gestiegen .',
#   'en_word_idx': [],
#   'de_word_idx': []},
#  {'idx': 4,
#   'en_text': 'gold prices are extremely sensitive to global interest rate movements .',
#   'de_text': 'der goldpreis ist extrem empfindlich hinsichtlich globaler veranderungen des zinssatzes .',
#   'en_word_idx': [],
#   'de_word_idx': []}]

# %%
len(data_norm) # dataset contains still 33k observations
# Out:
# 33048

# %%
import numpy as np
import math
import random
import copy
import tqdm
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn.utils import clip_grad_norm_

# %%
# Set seeds for reproducibility
SEED = 42
torch.manual_seed(SEED)
random.seed(SEED)
np.random.seed(SEED)

data = copy.deepcopy(data_norm)
# Shuffling the data
# dataset_shuffled = dataset.shuffle(seed=42)
random.shuffle(data)
# Splitting the data
data_train = data[:15000]
data_val = data[15000:18500]
data_test = data[18500:22000]

# %%
len_train = len(data_train)
len_val = len(data_val)
len_test = len(data_test)
print(f'train data length: {len_train} \nval data length: {len_val} \ntest data length: {len_test}')
# Out:
# train data length: 15000
# val data length: 3500
# test data length: 3500

# %%
from torch.utils.data import Dataset, DataLoader
import torch

class TranslationDataset(Dataset):
    def __init__(self, data):
        self.data = data

    # We return the length of the dataset
    def __len__(self):
        return len(self.data)

    # We return the idx'th sample
    def __getitem__(self, idx):
        return {
            'idx': idx,
            'en_word_idx': torch.tensor(self.data[idx]['en_word_idx']).long(),
            'de_word_idx': torch.tensor(self.data[idx]['de_word_idx']).long(),
        }

# %%
train_data = TranslationDataset(data_train)
val_data = TranslationDataset(data_val)
test_data = TranslationDataset(data_test)

# %%
train_data[0]
# Out:
# {'idx': 0,
#  'en_word_idx': tensor([], dtype=torch.int64),
#  'de_word_idx': tensor([], dtype=torch.int64)}

# %%
len(train_data), len(val_data), len(test_data)
# Out:
# (15000, 3500, 3500)

# %% [markdown]
# ### Build the vocabulary and word embedding matrix
#
# We now have all our data. Let's build the vocabulary and prepare the word-embeddings for the next steps **FOR EACH LANGUAGE**.

# %%
vocabulary = {'en': set(), 'de': set()}

for lang in ('en', 'de'):
  for sample in train_data.data: # Pay attention we only use the training set!
    for token in sample['{}_text'.format(lang)].split(): # tokenize
      vocabulary[lang].add(token)
  print(lang, len(vocabulary[lang]))
# Out:
# en 11472
# de 16705

# %%
# Create the mapping word - index and vice-versa
word2idx = {'en': {'_PAD_': 0, '_UNK_': 1, '_SOS_': 2, '_EOS_': 3},
            'de': {'_PAD_': 0, '_UNK_': 1, '_SOS_': 2, '_EOS_': 3}}

idx2word = {'en': {}, 'de': {}}
for lang in ('en', 'de'):
  for word in vocabulary[lang]:
    word2idx[lang][word] = len(word2idx[lang])
  idx2word[lang] = {idx:word for word, idx in word2idx[lang].items()}
  print(word2idx[lang])
# Out:
# {'_PAD_': 0, '_UNK_': 1, '_SOS_': 2, '_EOS_': 3, 'hand': 4, 'want': 5, 'smile': 6, 'hardships': 7, 'engagement': 8, 'extremely': 9, 'stress': 10, 'fallout': 11, 'koreans': 12, 'cooperating': 13, 'comparison': 14, 'enthusiasm': 15, 'stagnate': 16, 'beggaring': 17, 'twice': 18, 'sustainability': 19, 'fourier': 20, 'participation': 21, 'indexing': 22, 'even': 23, 'demography': 24, 'emotional': 25, 'palace': 26, 'accuse': 27, 'hal': 28, 'imprisoned': 29, 'emphasis': 30, 'soup': 31, 'sealevel': 32, 'ghost': 33, 'agrees': 34, 'pacta': 35, 'pretence': 36, 'hobble': 37, 'banal': 38, 'arbitrage': 39, 'documented': 40, 'immobility': 41, 'communists': 42, 'views': 43, 'governance': 44, 'drug': 45, 'crossroads': 46, 'enormous': 47, 'mountain': 48, 'kinds': 49, 'textiles': 50, 'fuse': 51, 'afraid': 52, 'blanket': 53, 'columbine': 54, 'dissident': 55, 'favorite': 56, 'catalyzed': 57, 'woes': 58, 'mismanagement': 59, 'shall': 60, 'gilts': 61, 'neurons': 62, 'shuttle': 63, 'capture': 64, 'incomparably': 65, 'epidemics': 66, 'fantasy': 67, 'harder': 68, 'efficacy': 69, 'stressful': 70, 'inspire': 71, 'worsened': 72, 'praktik': 73, 'polanski': 74, 'hardship': 75, 'hit': 76, 'fights': 77, 'debate': 78, 'insisting': 79, 'hurrrah': 80, 'whales': 81, 'productivity': 82, 'seeks': 83, 'mario': 84, 'ballots': 85, 'bleach': 86, 'behaved': 87, 'ethnic': 88, 'ponzi': 89, 'sidwell': 90, 'pointless': 91, 'businesses': 92, 'preventing': 93, 'finished': 94, 'loathe': 95, 'indicate': 96, 'spiraled': 97, 'reduces': 98, 'risen': 99, 'worked': 100, 'authoritarian': 101, 'targets': 102, 'humiliating': 103, 'netanyahu': 104, 'shouldn': 105, 'sequences': 106, 'dysfunctional': 107, 'tumor': 108, 'negotiations': 109, 'notoriously': 110, 'entangling': 111, 'alibis': 112, 'concerted': 113, 'construction': 114, 'exit': 115, 'bullish': 116, 'indirectly': 117, 'art': 118, 'slave': 119, 'series': 120, 'odd': 121, 'cries': 122, 'soothing': 123, 'wastewater': 124, 'mugabe': 125, 'amorphous': 126, 'calling': 127, 'peak': 128, 'biases': 129, 'frets': 130, 'deregulator': 131, 'patch': 132, 'yushchenko': 133, 'secrets': 134, 'furiously': 135, 'sets': 136, 'moving': 137, 'doctrines': 138, 'violated': 139, 'antimicrobial': 140, 'tune': 141, 'wharton': 142, 'aims': 143, 'adventures': 144, 'downright': 145, 'beehive': 146, 'viable': 147, 'arose': 148, 'local': 149, 'part': 150, 'ark': 151, 'films': 152, 'slower': 153, 'check': 154, 'thousands': 155, 'remote': 156, 'ecowas': 157, 'polluters': 158, 'calibrated': 159, 'easing': 160, 'revision': 161, 'alasan': 162, 'magnified': 163, 'harmony': 164, 'tip': 165, 'accompanies': 166, 'dissolved': 167, 'conclusion': 168, 'unequal': 169, 'determined': 170, 'entirely': 171, 'sharon': 172, 'bilateral': 173, 'unemployed': 174, 'consequences': 175, 'physicist': 176, 'inspiring': 177, 'borders': 178, 'democrat': 179, 'moon': 180, 'foundation': 181, 'convicts': 182, 'balanced': 183, 'objected': 184, 'predictions': 185, 'partly': 186, 'brief': 187, 'remained': 188, 'worthy': 189, 'directions': 190, 'outstripping': 191, 'russia': 192, 'grit': 193, 'memories': 194, 'advisers': 195, 'keep': 196, 'eban': 197, 'critical': 198, 'recover': 199, 'terrorists': 200, 'autonomy': 201, 'horse': 202, 'clarke': 203, 'coordinate': 204, 'vibrant': 205, 'liberalism': 206, 'headscarves': 207, 'buffett': 208, 'carries': 209, 'puppies': 210, 'rescue': 211, 'unnecessarily': 212, 'celebrations': 213, 'purchase': 214, 'retrench': 215, 'unacceptably': 216, 'socialist': 217, 'audiences': 218, 'hobby': 219, 'offing': 220, 'republicans': 221, 'once': 222, 'planes': 223, 'fulfilled': 224, 'timetable': 225, 'yang': 226, 'underdevelopment': 227, 'unprotected': 228, 'sagacious': 229, 'hardest': 230, 'sendiri': 231, 'libyans': 232, 'expanding': 233, 'unsafe': 234, 'celebrating': 235, 'sunni': 236, 'milosevic': 237, 'banks': 238, 'essentially': 239, 'fled': 240, 'qualified': 241, 'satu': 242, 'pentingnya': 243, 'statistical': 244, 'method': 245, 'progressively': 246, 'overwhelmed':  ...
# {'_PAD_': 0, '_UNK_': 1, '_SOS_': 2, '_EOS_': 3, 'pulverfass': 4, 'hand': 5, 'ausgestaltung': 6, 'textilien': 7, 'berechtigt': 8, 'erzeugung': 9, 'verschleppen': 10, 'engagement': 11, 'naturwissenschaftliche': 12, 'lebensmittelverschwendung': 13, 'stress': 14, 'vierte': 15, 'illegitime': 16, 'finanzinstitute': 17, 'zollhauser': 18, 'kollektives': 19, 'eingegangen': 20, 'glorreichen': 21, 'hinausschie': 22, 'gordische': 23, 'weise': 24, 'uberschlagen': 25, 'anlass': 26, 'potenziellem': 27, 'bulgarien': 28, 'eigentlichen': 29, 'acht': 30, 'studienteilnehmer': 31, 'herstellung': 32, 'zynismus': 33, 'schwach': 34, 'prasent': 35, 'verstarkt': 36, 'dauern': 37, 'bereinigung': 38, 'unbesicherten': 39, 'abwickeln': 40, 'fourier': 41, 'hugel': 42, 'damaskus': 43, 'terrorhilfe': 44, 'franzosen': 45, 'verbindet': 46, 'ungreifbaren': 47, 'rache': 48, 'zerbricht': 49, 'verbundeten': 50, 'hysterie': 51, 'soup': 52, 'sealevel': 53, 'pacta': 54, 'hinnehmen': 55, 'atomzeitalter': 56, 'vernetzt': 57, 'banal': 58, 'arbitrage': 59, 'insolventer': 60, 'mancherlei': 61, 'veroffentliche': 62, 'reprasentantenhaus': 63, 'kehren': 64, 'tun': 65, 'governance': 66, 'verwenden': 67, 'blase': 68, 'typisch': 69, 'geopolitische': 70, 'flirts': 71, 'naht': 72, 'antworten': 73, 'verwirklichen': 74, 'columbine': 75, 'dissident': 76, 'treibt': 77, 'bitterster': 78, 'bemerkenswert': 79, 'nordkorea': 80, 'konvois': 81, 'schwierig': 82, 'schottlands': 83, 'bankenkrise': 84, 'gilts': 85, 'vorn': 86, 'anderten': 87, 'herrschaft': 88, 'shuttle': 89, 'beunruhigen': 90, 'kenianische': 91, 'zwingen': 92, 'polanski': 93, 'allzu': 94, 'nuancen': 95, 'einfache': 96, 'unbeschreiblich': 97, 'energiegesellschaften': 98, 'vorzuge': 99, 'schatzen': 100, 'betracht': 101, 'unheilverkundend': 102, 'iraker': 103, 'ergabe': 104, 'mario': 105, 'aufgedeckt': 106, 'inspektoren': 107, 'einiger': 108, 'lavendeldecke': 109, 'fleischessen': 110, 'forderungen': 111, 'sidwell': 112, 'erklarungsmuster': 113, 'langweiliges': 114, 'chronik': 115, 'markte': 116, 'millenium': 117, 'bedrohungen': 118, 'datenlecks': 119, 'pattsituation': 120, 'eineinhalb': 121, 'respektabel': 122, 'risikoreiche': 123, 'manegen': 124, 'erschopftes': 125, 'wirtschaftswissenschaftliche': 126, 'zugeln': 127, 'nachdruck': 128, 'haben': 129, 'bedroht': 130, 'mundtot': 131, 'alibis': 132, 'gewachsen': 133, 'einkunfte': 134, 'profunde': 135, 'verwaltungsrat': 136, 'hervorstehenden': 137, 'heute': 138, 'unlauterkeit': 139, 'einkommenssteuern': 140, 'harter': 141, 'palaste': 142, 'breiterer': 143, 'regierungsvertreter': 144, 'bevorzugte': 145, 'art': 146, 'billige': 147, 'gnade': 148, 'zeitgenossischer': 149, 'weist': 150, 'tatsachlich': 151, 'debatte': 152, 'formt': 153, 'koniginnen': 154, 'illiberalen': 155, 'selbstzensur': 156, 'mugabe': 157, 'sozialprodukt': 158, 'welbys': 159, 'botschaftern': 160, 'anekdoten': 161, 'stellungnahmen': 162, 'zwecklos': 163, 'heutige': 164, 'dusteren': 165, 'renditen': 166, 'gleichgultig': 167, 'stabilitats': 168, 'achse': 169, 'belegen': 170, 'spuren': 171, 'entscheiden': 172, 'gekennzeichnet': 173, 'wharton': 174, 'hollandische': 175, 'neuheit': 176, 'leisten': 177, 'vertrauensspiel': 178, 'technokraten': 179, 'kernenergie': 180, 'ausgingen': 181, 'wahren': 182, 'anschuldigung': 183, 'obsiegte': 184, 'steuerung': 185, 'ecowas': 186, 'prufung': 187, 'gespendete': 188, 'schichten': 189, 'antrag': 190, 'dominikaner': 191, 'wirtschaftsstrategie': 192, 'wie': 193, 'hypothese': 194, 'prognose': 195, 'unangebrachte': 196, 'mutigere': 197, 'gemischter': 198, 'verbinden': 199, 'geschehnisse': 200, 'sonderberater': 201, 'disput': 202, 'ackerland': 203, 'berliner': 204, 'staatsangehorigkeit': 205, 'sharon': 206, 'erkrankungen': 207, 'errichten': 208, 'katzen': 209, 'extremen': 210, 'winzige': 211, 'willen': 212, 'informationskrieg': 213, 'moon': 214, 'foundation': 215, 'nigerianisches': 216, 'gesprochen': 217, 'offentliche': 218, 'widerstandsfahig': 219, 'absolut': 220, 'zweck': 221, 'brief': 222, 'h ...

# %%
idx2word['en']
# Out:
# {0: '_PAD_',
#  1: '_UNK_',
#  2: '_SOS_',
#  3: '_EOS_',
#  4: 'hand',
#  5: 'want',
#  6: 'smile',
#  7: 'hardships',
#  8: 'engagement',
#  9: 'extremely',
#  10: 'stress',
#  11: 'fallout',
#  12: 'koreans',
#  13: 'cooperating',
#  14: 'comparison',
#  15: 'enthusiasm',
#  16: 'stagnate',
#  17: 'beggaring',
#  18: 'twice',
#  19: 'sustainability',
#  20: 'fourier',
#  21: 'participation',
#  22: 'indexing',
#  23: 'even',
#  24: 'demography',
#  25: 'emotional',
#  26: 'palace',
#  27: 'accuse',
#  28: 'hal',
#  29: 'imprisoned',
#  30: 'emphasis',
#  31: 'soup',
#  32: 'sealevel',
#  33: 'ghost',
#  34: 'agrees',
#  35: 'pacta',
#  36: 'pretence',
#  37: 'hobble',
#  38: 'banal',
#  39: 'arbitrage',
#  40: 'documented',
#  41: 'immobility',
#  42: 'communists',
#  43: 'views',
#  44: 'governance',
#  45: 'drug',
#  46: 'crossroads',
#  47: 'enormous',
#  48: 'mountain',
#  49: 'kinds',
#  50: 'textiles',
#  51: 'fuse',
#  52: 'afraid',
#  53: 'blanket',
#  54: 'columbine',
#  55: 'dissident',
#  56: 'favorite',
#  57: 'catalyzed',
#  58: 'woes',
#  59: 'mismanagement',
#  60: 'shall',
#  61: 'gilts',
#  62: 'neurons',
#  63: 'shuttle',
#  64: 'capture',
#  65: 'incomparably',
#  66: 'epidemics',
#  67: 'fantasy',
#  68: 'harder',
#  69: 'efficacy',
#  70: 'stressful',
#  71: 'inspire',
#  72: 'worsened',
#  73: 'praktik',
#  74: 'polanski',
#  75: 'hardship',
#  76: 'hit',
#  77: 'fights',
#  78: 'debate',
#  79: 'insisting',
#  80: 'hurrrah',
#  81: 'whales',
#  82: 'productivity',
#  83: 'seeks',
#  84: 'mario',
#  85: 'ballots',
#  86: 'bleach',
#  87: 'behaved',
#  88: 'ethnic',
#  89: 'ponzi',
#  90: 'sidwell',
#  91: 'pointless',
#  92: 'businesses',
#  93: 'preventing',
#  94: 'finished',
#  95: 'loathe',
#  96: 'indicate',
#  97: 'spiraled',
#  98: 'reduces',
#  99: 'risen',
#  100: 'worked',
#  101: 'authoritarian',
#  102: 'targets',
#  103: 'humiliating',
#  104: 'netanyahu',
#  105: 'shouldn',
#  106: 'sequences',
#  107: 'dysfunctional',
#  108: 'tumor',
#  109: 'negotiations',
#  110: 'notoriously',
#  111: 'entangling',
#  112: 'alibis',
#  113: 'concerted',
#  114: 'construction',
#  115: 'exit',
#  116: 'bullish',
#  117: 'indirectly',
#  118: 'art',
#  119: 'slave',
#  120: 'series',
#  121: 'odd',
#  122: 'cries',
#  123: 'soothing',
#  124: 'wastewater',
#  125: 'mugabe',
#  126: 'amorphous',
#  127: 'calling',
#  128: 'peak',
#  129: 'biases',
#  130: 'frets',
#  131: 'deregulator',
#  132: 'patch',
#  133: 'yushchenko',
#  134: 'secrets',
#  135: 'furiously',
#  136: 'sets',
#  137: 'moving',
#  138: 'doctrines',
#  139: 'violated',
#  140: 'antimicrobial',
#  141: 'tune',
#  142: 'wharton',
#  143: 'aims',
#  144: 'adventures',
#  145: 'downright',
#  146: 'beehive',
#  147: 'viable',
#  148: 'arose',
#  149: 'local',
#  150: 'part',
#  151: 'ark',
#  152: 'films',
#  153: 'slower',
#  154: 'check',
#  155: 'thousands',
#  156: 'remote',
#  157: 'ecowas',
#  158: 'polluters',
#  159: 'calibrated',
#  160: 'easing',
#  161: 'revision',
#  162: 'alasan',
#  163: 'magnified',
#  164: 'harmony',
#  165: 'tip',
#  166: 'accompanies',
#  167: 'dissolved',
#  168: 'conclusion',
#  169: 'unequal',
#  170: 'determined',
#  171: 'entirely',
#  172: 'sharon',
#  173: 'bilateral',
#  174: 'unemployed',
#  175: 'consequences',
#  176: 'physicist',
#  177: 'inspiring',
#  178: 'borders',
#  179: 'democrat',
#  180: 'moon',
#  181: 'foundation',
#  182: 'convicts',
#  183: 'balanced',
#  184: 'objected',
#  185: 'predictions',
#  186: 'partly',
#  187: 'brief',
#  188: 'remained',
#  189: 'worthy',
#  190: 'directions',
#  191: 'outstripping',
#  192: 'russia',
#  193: 'grit',
#  194: 'memories',
#  195: 'advisers',
#  196: 'keep',
#  197: 'eban',
#  198: 'critical',
#  199: 'recover',
#  200: 'terrorists',
#  201: 'autonomy',
#  202: 'horse',
#  203: 'clarke',
#  204: 'coordinate',
#  205: 'vibrant',
#  206: 'liberalism',
#  207: 'headscarves',
#  208: 'buffett',
#  209: 'carries',
#  210: 'puppies',
#  211: 'rescue',
#  212: 'unnecessarily',
#  213: 'celebrations',
#  214: 'purchase',
#  215: 'retrench',
#  216: 'unacceptably',
#  217: 'socialist',
#  218: 'audiences',
#  219: 'hobby',
#  220: 'offing',
#  221: 'republicans',
#  222: 'once',
#  223: 'planes',
#  224: 'fulfilled',
#  225: 'timetable',
#  226: 'yang',
#  227: 'underdevelopment',
#  228: 'unprotected',
#  229: 'sagacious',
#  230: 'hardest',
#  231: 'sendiri',
#  232: 'libyans',
#  233: 'expanding',
#  234: 'unsafe',
#  235: 'celebrating',
#  236: 'sunni',
#  237: 'milosevic',
#  238: 'banks',
#  239: 'essentially',
#  240: 'fled',
#  241: 'qualified',
#  242: 'satu',
#  243: 'pentingnya',
#  244: 'statistical',
#  245: 'method',
#  246: 'progressively',
#  247: 'overwhelmed',
#  248: 'viruses',
#  249: 'politicized',
#  250: 'data',
#  251: 'contaminated',
#  252: 'wenceslas',
#  253: 'spiral',
#  254: 'cheat',
#  255: 'year',
#  256: 'recognizing',
#  257: 'sustained',
#  258: 'preconditions',
#  259: 'indistinct',
#  260: 'stopping',
#  261: 'blamed',
#  262: 'indian',
#  263: 'cows',
#  264: 'tenaciously',
#  265: 'tzipi',
#  266: 'strategy',
#  267: 'keseimbangan',
#  268: 'preachers',
#  269: 'passion',
#  270: 'dhaka',
#  271: 'politics',
#  272: 'sorry',
#  273: 'stay',
#  274: 'deregulation',
#  275: 'why',
#  276: 'lively',
#  277: 'municipalities',
#  278: 'ayatollah',
#  279: 'solzhenitsyn',
#  280: 'sun',
#  281: 'net',
#  282: 'inexcusable',
#  283: 'vitamin',
#  284: 'mount',
#  285: 'potentials',
#  286: 'contacts',
#  287: 'sometimes',
#  288: 'darkness',
#  289: 'ataturk',
#  290: 'myriad',
#  291: 'searching',
#  292: 'outward',
#  293: 'stubbornness',
#  294: 'correct',
#  295: 'proposes',
#  296: 'explicit',
#  297: 'insuring',
#  298: 'incompetence',
#  299: 'penyangkal',
#  300: 'sufficiently',
#  301: 'radicalization',
#  302: 'terrorized',
#  303: 'evaluating',
#  304: '.edu',
#  305: 'atas',
#  306: 'senior',
#  307: 'prime',
#  308: 'clan',
#  309: 'mobile',
#  310: 'artificial',
#  311: 'ebbing',
#  312: 'instantly',
#  313: 'ceded',
#  314: 'moods',
#  315: 'dark',
#  316: 'resonate',
#  317: 'devoting',
#  318: 'refer',
#  319: 'airtime',
#  320: 'surrounded',
#  321: 'corner',
#  322: 'brooks',
#  323: 'complexity',
#  324: 'exposes',
#  325: 'propaganda',
#  326: 'freedoms',
#  327: 'less',
#  328: 'owing',
#  329: 'bacteria',
#  330: '.project',
#  331: 'coefficient',
#  332: 'minyak',
#  333: 'darfur',
#  334: 'prevalence',
#  335: 'mata',
#  336: 'bureaucracy',
#  337: 'spectrum',
#  338: 'characteristics',
#  339: 'm',
#  340: 'worn',
#  341: 'agriculture',
#  342: 'undervalued',
#  343: 'relates',
#  344: 'stalinism',
#  345: 'splendid',
#  346: 'await',
#  347: 'kids',
#  348: 'mainstream',
#  349: 'ambivalent',
#  350: 'objectives',
#  351: 'leprosy',
#  352: 'energy',
#  353: 'month',
#  354: 'instigated',
#  355: 'unlucky',
#  356: 'fiction',
#  357: 'enthusiasts',
#  358: 'malthus',
#  359: 'harnessing',
#  360: 'discretion',
#  361: 'task',
#  362: 'retard',
#  363: 'involved',
#  364: 'controvert',
#  365: 'refusal',
#  366: 'hijau',
#  367: 'dictator',
#  368: 'allah',
#  369: 'interpret',
#  370: 'mcconnell',
#  371: 'prototype',
#  372: 'budget',
#  373: 'unknown',
#  374: 'crops',
#  375: 'diluting',
#  376: 'independence',
#  377: 'delphi',
#  378: 'incursion',
#  379: 'detected',
#  380: 'bretton',
#  381: 'secondly',
#  382: 'calculation',
#  383: 'balked',
#  384: 'dibiarkan',
#  385: 'diverse',
#  386: 'binyamin',
#  387: 'centuries',
#  388: 'chamberlain',
#  389: 'trademark',
#  390: 'spectacles',
#  391: 'sight',
#  392: 'kovalyov',
#  393: 'impunity',
#  394: 'pursuing',
#  395: 'disintegration',
#  396: 'seawater',
#  397: 'former',
#  398: 'variables',
#  399: 'organ',
#  400: 'moment',
#  401: 'kishi',
#  402: 'surrendered',
#  403: 'malays',
#  404: 'gadgets',
#  405: 'ultimate',
#  406: 'growers',
#  407: 'tripled',
#  408: 'loser',
#  409: 'own',
#  410: 'fizzled',
#  411: 'absurdly',
#  412: 'marxist',
#  413: 'commitment',
#  414: 'enam',
#  415: 'antidote',
#  416: 'conservatively',
#  417: 'pie',
#  418: 'reactionaries',
#  419: 'governing',
#  420: 'servanda',
#  421: 'ukrainians',
#  422: 'menyisakan',
#  423: 'technocrats',
#  424: 'pig',
#  425: 'kennedy',
#  426: 'rises',
#  427: 'ccp',
#  428: 'n',
#  429: 'bloodstained',
#  430: 'scare',
#  431: 'disappoints',
#  432: 'aunts',
#  433: 'previously',
#  434: 'horrifying',
#  435: 'undercover',
#  436: 'hubris',
#  437: 'caplin',
#  438: 'expression',
#  439: 'city',
#  440: 'unleash',
#  441: 'go',
#  442: 'freddie',
#  443: 'scary',
#  444: 'constitutional',
#  445: 'entry',
#  446: 'kaiser',
#  447: 'ease',
#  448: 'equals',
#  449: 'fresh',
#  450: 'sunnis',
#  451: 'appalled',
#  452: 'intends',
#  453: 'pacifism',
#  454: 'hongdong',
#  455: 'average',
#  456: 'technologically',
#  457: 'evening',
#  458: 'exhibited',
#  459: 'taught',
#  460: 'borrow',
#  461: 'eliminated',
#  462: 'underemployed',
#  463: 'flatter',
#  464: 'unevenly',
#  465: 'try',
#  466: 'demographic',
#  467: 'dries',
#  468: 'tsarist',
#  469: 'entitled',
#  470: 'worldcom',
#  471: 'finnish',
#  472: 'least',
#  473: 'starving',
#  474: 'google',
#  475: 'strengthen',
#  476: 'cart',
#  477: 'touts',
#  478: 'uber',
#  479: 'education',
#  480: 'compassionate',
#  481: 'connecting',
#  482: 'headlines',
#  483: 'levees',
#  484: 'generous',
#  485: 'bore',
#  486: 'varies',
#  487: 'bleakly',
#  488: 'prisoner',
#  489: 'significance',
#  490: 'arise',
#  491: 'competitiveness',
#  492: 'china',
#  493: 'galvanized',
#  494: 'sesame',
#  495: 'consumption',
#  496: 'deepened',
#  497: 'eerie',
#  498: 'holders',
#  499: 'counterweight',
#  500: 'urgently',
#  501: 'masters',
#  502: 'educated',
#  503: 'suffers',
#  504: 'klevyi',
#  505: 'standstill',
#  506: 'felt',
#  507: 'decreasing',
#  508: 'revival',
#  509: 'feminists',
#  510: 'drove',
#  511: 'proving',
#  512: 'perverted',
#  513: 'teknologi',
#  514: 'compensation',
#  515: 'africa',
#  516: 'velvet',
#  517: 'juan',
#  518: 'retraining',
#  519: 'evacuate',
#  520: 'report',
#  521: 'megatrend',
#  522: 'survived',
#  523: 'purchasing',
#  524: 'understanding',
#  525: 'precarious',
#  526: 'upward',
#  527: 'boardroom',
#  528: 'heralded',
#  529: 'baverez',
#  530: 'wear',
#  531: 'shut',
#  532: 'bumi',
#  533: 'civilizations',
#  534: 'better',
#  535: 'hayek',
#  536: 'level',
#  537: 'mourning',
#  538: 'continental',
#  539: 'continuous',
#  540: 'expunged',
#  541: 'boldness',
#  542: 'euthanasia',
#  543: 'tetapi',
#  544: 'dioxide',
#  545: 'scottish',
#  546: 'patronage',
#  547: 'generation',
#  548: 'generational',
#  549: 'islamist',
#  550: 'govern',
#  551: 'settlements',
#  552: 'distorted',
#  553: 'radical',
#  554: 'sweetener',
#  555: 'designated',
#  556: 'putsch',
#  557: 'resounding',
#  558: 'waited',
#  559: 'motivation',
#  560: 'occur',
#  561: 'traits',
#  562: 'realists',
#  563: 'inevitably',
#  564: 'embarrassment',
#  565: 'assemble',
#  566: 'assessments',
#  567: 'circumscribing',
#  568: 'white',
#  569: 'naming',
#  570: 'maradona',
#  571: 'compatriots',
#  572: 'prudent',
#  573: 'strongly',
#  574: 'punish',
#  575: 'milisi',
#  576: 'cancer',
#  577: 'place',
#  578: 'chair',
#  579: 'reunion',
#  580: 'heyday',
#  581: 'boxer',
#  582: 'resolute',
#  583: 'pet',
#  584: 'hopeless',
#  585: 'approach',
#  586: 'ekonomi',
#  587: 'deny',
#  588: 'trajectory',
#  589: 'topical',
#  590: 'diseases',
#  591: 'categories',
#  592: 'responses',
#  593: 'deception',
#  594: 'carry',
#  595: 'hussein',
#  596: 'dishes',
#  597: 'discouraging',
#  598: 'innovators',
#  599: 'begun',
#  600: 'everybody',
#  601: 'secretary',
#  602: 'crime',
#  603: 'tail',
#  604: 'ownership',
#  605: 'federal',
#  606: 'customization',
#  607: 'pathetic',
#  608: 'gap',
#  609: 'far',
#  610: 'protocol',
#  611: 'loss',
#  612: 'polio',
#  613: 'calibrating',
#  614: 'managing',
#  615: 'discussing',
#  616: 'inappropriate',
#  617: 'alchemy',
#  618: 'contemplating',
#  619: 'caucasian',
#  620: 'operation',
#  621: 'oligarchs',
#  622: 'rates',
#  623: 'disdainful',
#  624: 'humility',
#  625: 'faulty',
#  626: 'gained',
#  627: 'sheikh',
#  628: 'four',
#  629: 'linkage',
#  630: 'ago',
#  631: 'malala',
#  632: 'unequivocally',
#  633: 'judiciary',
#  634: 'settlement',
#  635: 'triumphalism',
#  636: 'deja',
#  637: 'jihadi',
#  638: 'exporters',
#  639: 'secured',
#  640: 'gambit',
#  641: 'lawless',
#  642: 'items',
#  643: 'unnecessary',
#  644: 'planned',
#  645: 'sd',
#  646: 'fingerprints',
#  647: 'keadaan',
#  648: 'hysteria',
#  649: 'clients',
#  650: 'labour',
#  651: 'board',
#  652: 'inconceivable',
#  653: 'referendum',
#  654: 'beginning',
#  655: 'caroline',
#  656: 'judge',
#  657: 'unambiguously',
#  658: 'favored',
#  659: 'contrast',
#  660: 'string',
#  661: 'outpace',
#  662: 'province',
#  663: 'identities',
#  664: 'tantrums',
#  665: 'reliably',
#  666: 'carta',
#  667: 'geographical',
#  668: 'misled',
#  669: 'cultures',
#  670: 'post',
#  671: 'avarice',
#  672: 'fat',
#  673: 'duped',
#  674: 'erased',
#  675: 'relief',
#  676: 'annihilation',
#  677: 'madness',
#  678: 'flee',
#  679: 'impressive',
#  680: 'liars',
#  681: 'children',
#  682: 'evoked',
#  683: 'hair',
#  684: 'idomeneo',
#  685: 'hazards',
#  686: 'crackdown',
#  687: 'spain',
#  688: 'percent',
#  689: 'cleansing',
#  690: 'toxic',
#  691: 'henry',
#  692: 'conceit',
#  693: 'expecting',
#  694: 'nostalgia',
#  695: 'regularity',
#  696: 'hopeful',
#  697: 'shifts',
#  698: 'fraud',
#  699: 'gfci',
#  700: 'granted',
#  701: 'contest',
#  702: 'resiliency',
#  703: 'prevented',
#  704: 'paradise',
#  705: 'union',
#  706: 'him',
#  707: 'author',
#  708: 'helicopters',
#  709: 'strangulation',
#  710: 'norway',
#  711: 'cares',
#  712: 'forty',
#  713: 'plummet',
#  714: 'reduction',
#  715: 'nagged',
#  716: 'plain',
#  717: 'intensity',
#  718: 'first',
#  719: 'autograph',
#  720: 'corrupt',
#  721: 'instinctive',
#  722: 'costly',
#  723: 'geo',
#  724: 'sterilization',
#  725: 'languish',
#  726: 'basis',
#  727: 'azam',
#  728: 'alarming',
#  729: 'bailouts',
#  730: 'bulgaria',
#  731: 'baltimore',
#  732: 'entering',
#  733: 'empirical',
#  734: 'calculations',
#  735: 'pledge',
#  736: 'simply',
#  737: 'measured',
#  738: 'diluted',
#  739: 'barroso',
#  740: 'aren',
#  741: 'suspect',
#  742: 'shagari',
#  743: 'momentum',
#  744: 'presumed',
#  745: 'fortunately',
#  746: 'member',
#  747: 'ways',
#  748: 'caudillos',
#  749: 'excellent',
#  750: 'religion',
#  751: 'blinders',
#  752: 'acknowledge',
#  753: 'engage',
#  754: 'talks',
#  755: 'accomplishments',
#  756: 'wagons',
#  757: 'eastern',
#  758: 'depan',
#  759: 'coherent',
#  760: 'palestinians',
#  761: 'reagan',
#  762: 'specialists',
#  763: 'installation',
#  764: 'obstructing',
#  765: 'eschewed',
#  766: 'per',
#  767: 'kurang',
#  768: 'episodes',
#  769: 'rejoice',
#  770: 'frustrations',
#  771: 'lending',
#  772: 'contradictions',
#  773: 'unstuck',
#  774: 'deaths',
#  775: 'quarters',
#  776: 'democratizing',
#  777: 'nociceptive',
#  778: 'opinion',
#  779: 'subtleties',
#  780: 'novelty',
#  781: 'sidelined',
#  782: 'fared',
#  783: 'doesn',
#  784: 'helpless',
#  785: 'very',
#  786: 'overhangs',
#  787: 'conundrum',
#  788: 'exuberance',
#  789: 'ambit',
#  790: 'deceived',
#  791: 'curriculum',
#  792: 'friedman',
#  793: 'abjuring',
#  794: 'teflon',
#  795: 'quiver',
#  796: 'flip',
#  797: 'met',
#  798: 'bioethanol',
#  799: 'insecuritization',
#  800: 'scapegoats',
#  801: 'draft',
#  802: 'ahmedinejad',
#  803: 'seemed',
#  804: 'qe',
#  805: 'chinas',
#  806: 'involuntary',
#  807: 'extinction',
#  808: 'highly',
#  809: 'procurement',
#  810: 'combining',
#  811: 'revered',
#  812: 'salvador',
#  813: 'proposition',
#  814: 'departments',
#  815: 'berliners',
#  816: 'irresolution',
#  817: 'giving',
#  818: 'quite',
#  819: 'globe',
#  820: 'shops',
#  821: 'proactive',
#  822: 'kampf',
#  823: 'protested',
#  824: 'trilingual',
#  825: 'competency',
#  826: 'alluring',
#  827: 'separatism',
#  828: 'cashews',
#  829: 'incentives',
#  830: 'july',
#  831: 'collateral',
#  832: 'predicable',
#  833: 'legacy',
#  834: 'superconductors',
#  835: 'a',
#  836: 'humbled',
#  837: 'district',
#  838: 'disastrous',
#  839: 'undergraduate',
#  840: 'exhibit',
#  841: 'busur',
#  842: 'gandhi',
#  843: 'intractable',
#  844: 'showed',
#  845: 'describe',
#  846: 'controversial',
#  847: 'vosskuhle',
#  848: 'lone',
#  849: 'preventive',
#  850: 'physics',
#  851: 'passenger',
#  852: 'phelps',
#  853: 'array',
#  854: 'moderate',
#  855: 'nicer',
#  856: 'eliminating',
#  857: 'rubbing',
#  858: 'creative',
#  859: 'harms',
#  860: 'signals',
#  861: 'albanian',
#  862: 'natashas',
#  863: 'or',
#  864: 'crusading',
#  865: 'complicates',
#  866: 'corporatist',
#  867: 'swamp',
#  868: 'maligned',
#  869: 'upswing',
#  870: 'thatcher',
#  871: 'strains',
#  872: 'road',
#  873: 'monopolizing',
#  874: 'sharia',
#  875: 'facing',
#  876: 'mahmoud',
#  877: 'cop',
#  878: 'smarter',
#  879: 'activities',
#  880: 'reexamined',
#  881: 'accepted',
#  882: 'dodge',
#  883: 'produced',
#  884: 'blockade',
#  885: 'recapitalized',
#  886: 'turkmenistan',
#  887: 'proceeded',
#  888: 'bolstered',
#  889: 'hitting',
#  890: 'acclamation',
#  891: 'unifying',
#  892: 'provision',
#  893: 'burn',
#  894: 'rockets',
#  895: 'aspects',
#  896: 'cavallo',
#  897: 'indecision',
#  898: 'consumer',
#  899: 'cheap',
#  900: 'purchases',
#  901: 'khobragade',
#  902: 'reportedly',
#  903: 'kremlin',
#  904: 'packages',
#  905: 'suggest',
#  906: 'double',
#  907: 'central',
#  908: 'depreciation',
#  909: 'reunify',
#  910: 'shows',
#  911: 'proportional',
#  912: 'voters',
#  913: 'kita',
#  914: 'movements',
#  915: 'unbearable',
#  916: 'sail',
#  917: 'causality',
#  918: 'damaged',
#  919: 'sterilised',
#  920: 'shelters',
#  921: 'nationally',
#  922: 'contrasting',
#  923: 'moscow',
#  924: 'generally',
#  925: 'scrutinized',
#  926: 'arrival',
#  927: 'nobler',
#  928: 'impasse',
#  929: 'ward',
#  930: 'frightening',
#  931: 'wikileaky',
#  932: 'putin',
#  933: 'village',
#  934: 'essential',
#  935: 'animals',
#  936: 'memburuk',
#  937: 'simone',
#  938: 'clues',
#  939: 'suddenly',
#  940: 'venice',
#  941: 'qualities',
#  942: 'without',
#  943: 'passivity',
#  944: 'differentiate',
#  945: 'receptors',
#  946: 'extraordinarily',
#  947: 'expertise',
#  948: 'curious',
#  949: 'zuma',
#  950: 'separatist',
#  951: 'semite',
#  952: 'lifted',
#  953: 'dereliction',
#  954: 'heading',
#  955: 'bis',
#  956: 'schadenfreude',
#  957: 'defaulting',
#  958: 'plagued',
#  959: 'framework',
#  960: 'animated',
#  961: 'honni',
#  962: 'willing',
#  963: 'demagoguery',
#  964: 'termed',
#  965: 'tea',
#  966: 'abandoned',
#  967: 'ludicrous',
#  968: 'georgian',
#  969: 'jong',
#  970: 'diubah',
#  971: 'keynesians',
#  972: 'improbable',
#  973: 'mao',
#  974: 'isolation',
#  975: 'currencies',
#  976: 'boulanger',
#  977: 'jordanians',
#  978: 'suicide',
#  979: 'spins',
#  980: '.html',
#  981: 'linkages',
#  982: 'imitated',
#  983: 'wards',
#  984: 'imploded',
#  985: 'mengurangi',
#  986: 'advocates',
#  987: 'ambitions',
#  988: 'boe',
#  989: 'churchill',
#  990: 'nobody',
#  991: 'wonderful',
#  992: 'attlee',
#  993: 'stagnation',
#  994: 'hague',
#  995: 'field',
#  996: 'inhibiting',
#  997: 'bottcher',
#  998: 'it',
#  999: 'pro',
#  ...}

# %%
idx2word['de']
# Out:
# {0: '_PAD_',
#  1: '_UNK_',
#  2: '_SOS_',
#  3: '_EOS_',
#  4: 'pulverfass',
#  5: 'hand',
#  6: 'ausgestaltung',
#  7: 'textilien',
#  8: 'berechtigt',
#  9: 'erzeugung',
#  10: 'verschleppen',
#  11: 'engagement',
#  12: 'naturwissenschaftliche',
#  13: 'lebensmittelverschwendung',
#  14: 'stress',
#  15: 'vierte',
#  16: 'illegitime',
#  17: 'finanzinstitute',
#  18: 'zollhauser',
#  19: 'kollektives',
#  20: 'eingegangen',
#  21: 'glorreichen',
#  22: 'hinausschie',
#  23: 'gordische',
#  24: 'weise',
#  25: 'uberschlagen',
#  26: 'anlass',
#  27: 'potenziellem',
#  28: 'bulgarien',
#  29: 'eigentlichen',
#  30: 'acht',
#  31: 'studienteilnehmer',
#  32: 'herstellung',
#  33: 'zynismus',
#  34: 'schwach',
#  35: 'prasent',
#  36: 'verstarkt',
#  37: 'dauern',
#  38: 'bereinigung',
#  39: 'unbesicherten',
#  40: 'abwickeln',
#  41: 'fourier',
#  42: 'hugel',
#  43: 'damaskus',
#  44: 'terrorhilfe',
#  45: 'franzosen',
#  46: 'verbindet',
#  47: 'ungreifbaren',
#  48: 'rache',
#  49: 'zerbricht',
#  50: 'verbundeten',
#  51: 'hysterie',
#  52: 'soup',
#  53: 'sealevel',
#  54: 'pacta',
#  55: 'hinnehmen',
#  56: 'atomzeitalter',
#  57: 'vernetzt',
#  58: 'banal',
#  59: 'arbitrage',
#  60: 'insolventer',
#  61: 'mancherlei',
#  62: 'veroffentliche',
#  63: 'reprasentantenhaus',
#  64: 'kehren',
#  65: 'tun',
#  66: 'governance',
#  67: 'verwenden',
#  68: 'blase',
#  69: 'typisch',
#  70: 'geopolitische',
#  71: 'flirts',
#  72: 'naht',
#  73: 'antworten',
#  74: 'verwirklichen',
#  75: 'columbine',
#  76: 'dissident',
#  77: 'treibt',
#  78: 'bitterster',
#  79: 'bemerkenswert',
#  80: 'nordkorea',
#  81: 'konvois',
#  82: 'schwierig',
#  83: 'schottlands',
#  84: 'bankenkrise',
#  85: 'gilts',
#  86: 'vorn',
#  87: 'anderten',
#  88: 'herrschaft',
#  89: 'shuttle',
#  90: 'beunruhigen',
#  91: 'kenianische',
#  92: 'zwingen',
#  93: 'polanski',
#  94: 'allzu',
#  95: 'nuancen',
#  96: 'einfache',
#  97: 'unbeschreiblich',
#  98: 'energiegesellschaften',
#  99: 'vorzuge',
#  100: 'schatzen',
#  101: 'betracht',
#  102: 'unheilverkundend',
#  103: 'iraker',
#  104: 'ergabe',
#  105: 'mario',
#  106: 'aufgedeckt',
#  107: 'inspektoren',
#  108: 'einiger',
#  109: 'lavendeldecke',
#  110: 'fleischessen',
#  111: 'forderungen',
#  112: 'sidwell',
#  113: 'erklarungsmuster',
#  114: 'langweiliges',
#  115: 'chronik',
#  116: 'markte',
#  117: 'millenium',
#  118: 'bedrohungen',
#  119: 'datenlecks',
#  120: 'pattsituation',
#  121: 'eineinhalb',
#  122: 'respektabel',
#  123: 'risikoreiche',
#  124: 'manegen',
#  125: 'erschopftes',
#  126: 'wirtschaftswissenschaftliche',
#  127: 'zugeln',
#  128: 'nachdruck',
#  129: 'haben',
#  130: 'bedroht',
#  131: 'mundtot',
#  132: 'alibis',
#  133: 'gewachsen',
#  134: 'einkunfte',
#  135: 'profunde',
#  136: 'verwaltungsrat',
#  137: 'hervorstehenden',
#  138: 'heute',
#  139: 'unlauterkeit',
#  140: 'einkommenssteuern',
#  141: 'harter',
#  142: 'palaste',
#  143: 'breiterer',
#  144: 'regierungsvertreter',
#  145: 'bevorzugte',
#  146: 'art',
#  147: 'billige',
#  148: 'gnade',
#  149: 'zeitgenossischer',
#  150: 'weist',
#  151: 'tatsachlich',
#  152: 'debatte',
#  153: 'formt',
#  154: 'koniginnen',
#  155: 'illiberalen',
#  156: 'selbstzensur',
#  157: 'mugabe',
#  158: 'sozialprodukt',
#  159: 'welbys',
#  160: 'botschaftern',
#  161: 'anekdoten',
#  162: 'stellungnahmen',
#  163: 'zwecklos',
#  164: 'heutige',
#  165: 'dusteren',
#  166: 'renditen',
#  167: 'gleichgultig',
#  168: 'stabilitats',
#  169: 'achse',
#  170: 'belegen',
#  171: 'spuren',
#  172: 'entscheiden',
#  173: 'gekennzeichnet',
#  174: 'wharton',
#  175: 'hollandische',
#  176: 'neuheit',
#  177: 'leisten',
#  178: 'vertrauensspiel',
#  179: 'technokraten',
#  180: 'kernenergie',
#  181: 'ausgingen',
#  182: 'wahren',
#  183: 'anschuldigung',
#  184: 'obsiegte',
#  185: 'steuerung',
#  186: 'ecowas',
#  187: 'prufung',
#  188: 'gespendete',
#  189: 'schichten',
#  190: 'antrag',
#  191: 'dominikaner',
#  192: 'wirtschaftsstrategie',
#  193: 'wie',
#  194: 'hypothese',
#  195: 'prognose',
#  196: 'unangebrachte',
#  197: 'mutigere',
#  198: 'gemischter',
#  199: 'verbinden',
#  200: 'geschehnisse',
#  201: 'sonderberater',
#  202: 'disput',
#  203: 'ackerland',
#  204: 'berliner',
#  205: 'staatsangehorigkeit',
#  206: 'sharon',
#  207: 'erkrankungen',
#  208: 'errichten',
#  209: 'katzen',
#  210: 'extremen',
#  211: 'winzige',
#  212: 'willen',
#  213: 'informationskrieg',
#  214: 'moon',
#  215: 'foundation',
#  216: 'nigerianisches',
#  217: 'gesprochen',
#  218: 'offentliche',
#  219: 'widerstandsfahig',
#  220: 'absolut',
#  221: 'zweck',
#  222: 'brief',
#  223: 'haufigeren',
#  224: 'petrobas',
#  225: 'psychedelische',
#  226: 'geoffnet',
#  227: 'ertrinken',
#  228: 'sektors',
#  229: 'wachstumsmotor',
#  230: 'kontexte',
#  231: 'wirksamen',
#  232: 'beiprodukt',
#  233: 'unwichtige',
#  234: 'anstatt',
#  235: 'begrunung',
#  236: 'eban',
#  237: 'abschottung',
#  238: 'ausgehen',
#  239: 'solle',
#  240: 'justiz',
#  241: 'spezialisten',
#  242: 'serben',
#  243: 'marxismus',
#  244: 'eisernen',
#  245: 'spielers',
#  246: 'wasserqualitat',
#  247: 'georgien',
#  248: 'irren',
#  249: 'clarke',
#  250: 'mythen',
#  251: 'beruhmte',
#  252: 'chinafeindlich',
#  253: 'gleich',
#  254: 'fehleinschatzung',
#  255: 'vorzuglich',
#  256: 'atomwaffe',
#  257: 'konjunkturma',
#  258: 'abnormal',
#  259: 'besatzungszeit',
#  260: 'botschafter',
#  261: 'klaren',
#  262: 'flugels',
#  263: 'postkolonialen',
#  264: 'verstandigung',
#  265: 'bestandteil',
#  266: 'asymmetrien',
#  267: 'opiumkrieg',
#  268: 'skeptische',
#  269: 'tankstellen',
#  270: 'diener',
#  271: 'entwirrt',
#  272: 'segensreiche',
#  273: 'beschreibung',
#  274: 'entschlossenheit',
#  275: 'vorstandsvorsitzender',
#  276: 'hobby',
#  277: 'gespenst',
#  278: 'reaktionare',
#  279: 'wiedergeboren',
#  280: 'gewertet',
#  281: 'komitee',
#  282: 'dialog',
#  283: 'mehrzahl',
#  284: 'geschadet',
#  285: 'zielgerichtet',
#  286: 'energieproduzenten',
#  287: 'ausrichten',
#  288: 'mails',
#  289: 'zutaten',
#  290: 'verzogerungen',
#  291: 'konfrontation',
#  292: 'vertrauensdefizit',
#  293: 'integriertes',
#  294: 'psychologische',
#  295: 'milosevic',
#  296: 'banks',
#  297: 'eindrucksvoll',
#  298: 'beeindruckt',
#  299: 'zeitraum',
#  300: 'aufsehen',
#  301: 'drogenabhangigen',
#  302: 'erkannt',
#  303: 'uberprufung',
#  304: 'konservativen',
#  305: 'machtgleichgewicht',
#  306: 'denkmaler',
#  307: 'eingebrockt',
#  308: 'bedenklicher',
#  309: 'zwischen',
#  310: 'beschaffungswesen',
#  311: 'passiert',
#  312: 'bestimmen',
#  313: 'hungers',
#  314: 'stehende',
#  315: 'boj',
#  316: 'selektivitat',
#  317: 'data',
#  318: 'ungenugende',
#  319: 'ballfan',
#  320: 'marktzinssatze',
#  321: 'untersutzen',
#  322: 'gewisser',
#  323: 'medaillen',
#  324: 'trotzki',
#  325: 'belassen',
#  326: 'geplant',
#  327: 'zuzuordnen',
#  328: 'emissionsrechtehandel',
#  329: 'beschleunigen',
#  330: 'aufrecht',
#  331: 'formuliert',
#  332: 'schreiben',
#  333: 'schickt',
#  334: 'wissenschaftlich',
#  335: 'tzipi',
#  336: 'reprasentieren',
#  337: 'hierauf',
#  338: 'vorgelegten',
#  339: 'lass',
#  340: 'engagierte',
#  341: 'eingefuhrt',
#  342: 'beschlagnahme',
#  343: 'fischsuppe',
#  344: 'dhaka',
#  345: 'spielten',
#  346: 'ausgesetzt',
#  347: 'sozialstaaten',
#  348: 'zuvorgekommen',
#  349: 'horizont',
#  350: 'tauschungen',
#  351: 'trug',
#  352: 'wahltaktik',
#  353: 'zinssatzes',
#  354: 'einfach',
#  355: 'heimischen',
#  356: 'verbreitetes',
#  357: 'elemente',
#  358: 'ayatollah',
#  359: 'nachgeben',
#  360: 'mindere',
#  361: 'weiterentwickeln',
#  362: 'verworfen',
#  363: 'vorausgehen',
#  364: 'anhanger',
#  365: 'vitamin',
#  366: 'mount',
#  367: 'erstreckendes',
#  368: 'prokrustesbett',
#  369: 'unvermeidliche',
#  370: 'kollaps',
#  371: 'aktuellere',
#  372: 'polemik',
#  373: 'ruchlosester',
#  374: 'krasser',
#  375: 'ataturk',
#  376: 'regierungspartei',
#  377: 'wenigen',
#  378: 'verbesserungen',
#  379: 'leistungsorientiert',
#  380: 'ermoglichten',
#  381: 'rebellion',
#  382: 'institutionen',
#  383: 'geringere',
#  384: 'wale',
#  385: 'fortschritte',
#  386: 'heimatland',
#  387: 'deutlicher',
#  388: 'neuerfindung',
#  389: 'wirtschaftsaktivitat',
#  390: 'starke',
#  391: 'warme',
#  392: 'doktoren',
#  393: 'stocken',
#  394: 'dachgeschoss',
#  395: 'unwirksam',
#  396: 'eigentumsrechte',
#  397: '.edu',
#  398: 'voranzutreiben',
#  399: 'immerwahrender',
#  400: 'verwalten',
#  401: 'clan',
#  402: 'unternehmens',
#  403: 'blockiert',
#  404: 'zerrissen',
#  405: 'arm',
#  406: 'osterreich',
#  407: 'einzigartig',
#  408: 'tiefere',
#  409: 'unplausibel',
#  410: 'unvollendete',
#  411: 'fallstudie',
#  412: 'havanna',
#  413: 'indiens',
#  414: 'infolge',
#  415: 'selbstbewusste',
#  416: 'gemogelt',
#  417: 'europagegner',
#  418: 'faust',
#  419: 'rentensysteme',
#  420: 'wasserversorgung',
#  421: 'propaganda',
#  422: 'bemerkenswerte',
#  423: 'dichter',
#  424: 'liquiditat',
#  425: 'implantate',
#  426: 'stachen',
#  427: '.project',
#  428: 'verraten',
#  429: 'herbeifuhren',
#  430: 'antimikrobiellen',
#  431: 'darfur',
#  432: 'hinbekommen',
#  433: 'geplagt',
#  434: 'mata',
#  435: 'saudische',
#  436: 'verkauft',
#  437: 'arzneimittel',
#  438: 'bereut',
#  439: 'dissidenten',
#  440: 'erschwerend',
#  441: 'kriege',
#  442: 'akademischen',
#  443: 'schrankte',
#  444: 'frau',
#  445: 'energien',
#  446: 'typ',
#  447: 'wostok',
#  448: 'verdrangt',
#  449: 'philippinen',
#  450: 'erlebten',
#  451: 'staatsverschuldung',
#  452: 'blutigen',
#  453: 'koreanischer',
#  454: 'auffordert',
#  455: 'italien',
#  456: 'vorwand',
#  457: 'prufsteine',
#  458: 'mainstream',
#  459: 'ambivalent',
#  460: 'handelsgesprachen',
#  461: 'sieg',
#  462: 'lebensstil',
#  463: 'organisatorisches',
#  464: 'niederlandern',
#  465: 'verstanden',
#  466: 'assange',
#  467: 'technisch',
#  468: 'prozentwerte',
#  469: 'beschutzt',
#  470: 'zuende',
#  471: 'tot',
#  472: 'malthus',
#  473: 'ungeheuren',
#  474: 'wissen',
#  475: 'auswirkungen',
#  476: 'nichts',
#  477: 'verandern',
#  478: 'albanischen',
#  479: 'schuldner',
#  480: 'allah',
#  481: 'sahen',
#  482: 'budget',
#  483: 'ausland',
#  484: 'vereinigten',
#  485: 'coming',
#  486: 'rusten',
#  487: 'auslandsschulden',
#  488: 'fortschrittlichsten',
#  489: 'mekka',
#  490: 'typs',
#  491: 'luftfahrt',
#  492: 'arbeitslosenrate',
#  493: 'organisationseinheit',
#  494: 'verandert',
#  495: 'interpretieren',
#  496: 'monarchie',
#  497: 'freiheit',
#  498: 'delphi',
#  499: 'gewisserma',
#  500: 'weckruf',
#  501: 'bretton',
#  502: 'verlagert',
#  503: 'speist',
#  504: 'ergebnis',
#  505: 'dorthin',
#  506: 'freiheitskampfer',
#  507: 'chamberlain',
#  508: 'weitete',
#  509: 'nachste',
#  510: 'viehbestand',
#  511: 'ludwig',
#  512: 'erfolges',
#  513: 'weichem',
#  514: 'rechenschaft',
#  515: 'bauausgaben',
#  516: 'zitieren',
#  517: 'unseren',
#  518: 'vergutungen',
#  519: 'dazulernen',
#  520: 'moment',
#  521: 'bezeichnete',
#  522: 'kishi',
#  523: 'entwicklern',
#  524: 'lebenswelten',
#  525: 'gultig',
#  526: 'argentinier',
#  527: 'gesetzten',
#  528: 'hautkrebs',
#  529: 'unwetter',
#  530: 'satz',
#  531: 'gegenwart',
#  532: 'attacken',
#  533: 'verweht',
#  534: 'sagend',
#  535: 'angehauft',
#  536: 'zutraglich',
#  537: 'genaueren',
#  538: 'altruismus',
#  539: 'pauschale',
#  540: 'bestimmte',
#  541: 'hindernis',
#  542: 'vitale',
#  543: 'wetteifern',
#  544: 'sudkorea',
#  545: 'klares',
#  546: 'hauptopfer',
#  547: 'wege',
#  548: 'refugium',
#  549: 'durchgefuhrt',
#  550: 'niedrigeres',
#  551: 'energieprodukte',
#  552: 'vierten',
#  553: 'babys',
#  554: 'unterlassung',
#  555: 'selbstjustiz',
#  556: 'aufdrangen',
#  557: 'neuinfektionen',
#  558: 'servanda',
#  559: 'denkens',
#  560: 'historischen',
#  561: 'auswahlen',
#  562: 'missachtet',
#  563: 'menge',
#  564: 'kennedy',
#  565: 'mexiko',
#  566: 'kulturellen',
#  567: 'rechten',
#  568: 'fordermitteln',
#  569: 'freien',
#  570: 'pfeile',
#  571: 'ccp',
#  572: 'vermittelten',
#  573: 'photosynthese',
#  574: 'obsiegten',
#  575: 'englischen',
#  576: 'uberwunden',
#  577: 'anonyme',
#  578: 'stabilitatspaktes',
#  579: 'bedeutet',
#  580: 'hervorzubringen',
#  581: 'eindruck',
#  582: 'korrekte',
#  583: 'city',
#  584: 'skandinavische',
#  585: 'problematischsten',
#  586: 'freddie',
#  587: 'ausgabenkurzungen',
#  588: 'vorahnungen',
#  589: 'cashew',
#  590: 'internetbezogenen',
#  591: 'genetiker',
#  592: 'kaiser',
#  593: 'geiz',
#  594: 'verseucht',
#  595: 'waffengesetzen',
#  596: 'schlimm',
#  597: 'praferenzen',
#  598: 'stelle',
#  599: 'verringerung',
#  600: 'hongdong',
#  601: 'anstieg',
#  602: 'steht',
#  603: 'uberschritt',
#  604: 'langerfristige',
#  605: 'mitwirkung',
#  606: 'sprunge',
#  607: 'ozonmafia',
#  608: 'verbesserung',
#  609: 'vorwartssturmen',
#  610: 'konsumguter',
#  611: 'sokrates',
#  612: 'auszulosen',
#  613: 'ungereimtheiten',
#  614: 'risikomanagement',
#  615: 'machtkonzentration',
#  616: 'aquakultur',
#  617: 'sharons',
#  618: 'toren',
#  619: 'ungewissen',
#  620: 'krebserkrankungen',
#  621: 'unverstandlich',
#  622: 'einwohnern',
#  623: 'israelisch',
#  624: 'aufhaltsame',
#  625: 'falsche',
#  626: 'kurzen',
#  627: 'ruhms',
#  628: 'konzipiert',
#  629: 'vereinigungsfreiheit',
#  630: 'hochkrempeln',
#  631: 'gnadenlosen',
#  632: 'anleihe',
#  633: 'schmerzlindernden',
#  634: 'verhandelt',
#  635: 'unterschatzt',
#  636: 'verschlechtert',
#  637: 'marionette',
#  638: 'afghanische',
#  639: 'wiederaufgenommen',
#  640: 'kreditgeber',
#  641: 'urururenkeln',
#  642: 'mikrokreditgeber',
#  643: 'fruhe',
#  644: 'brennstoffen',
#  645: 'folgte',
#  646: 'least',
#  647: 'google',
#  648: 'einkommensschere',
#  649: 'oberhand',
#  650: 'urbanen',
#  651: 'haushalts',
#  652: 'uber',
#  653: 'hintergrundgerausch',
#  654: 'energische',
#  655: 'dutzend',
#  656: 'gefallt',
#  657: 'vertrauens',
#  658: 'finanzbummler',
#  659: 'vogel',
#  660: 'weiterziehen',
#  661: 'umweltschaden',
#  662: 'skandinavischen',
#  663: 'menschlicher',
#  664: 'uberraschender',
#  665: 'verweigerte',
#  666: 'punkten',
#  667: 'unterton',
#  668: 'anzuerkennen',
#  669: 'sicherheitspolitische',
#  670: 'erinnerungen',
#  671: 'sich',
#  672: 'losungsmechanismen',
#  673: 'entwicklungsbereich',
#  674: 'wiegen',
#  675: 'china',
#  676: 'justizreform',
#  677: 'darf',
#  678: 'massenvernichtungswaffen',
#  679: 'sendet',
#  680: 'empfinden',
#  681: 'durchgefuhrte',
#  682: 'einzuschlagen',
#  683: 'unzuverlassigen',
#  684: 'weiterzumachen',
#  685: 'foderation',
#  686: 'vergutung',
#  687: 'restrukturierungspolitik',
#  688: 'wohnungsmarkt',
#  689: 'verdacht',
#  690: 'ruttelte',
#  691: 'religionsschulen',
#  692: 'ausdruck',
#  693: 'kooperation',
#  694: 'lissabon',
#  695: 'feminismus',
#  696: 'nuklearkompromiss',
#  697: 'klevyi',
#  698: 'sicheren',
#  699: 'brennholz',
#  700: 'amerikanischer',
#  701: 'weitergereicht',
#  702: 'grundrechte',
#  703: 'vermutung',
#  704: 'herstellen',
#  705: 'chinesisch',
#  706: 'kapitaleigner',
#  707: 'allgemeiner',
#  708: 'industrie',
#  709: 'heimliche',
#  710: 'irrelevante',
#  711: 'festzulegen',
#  712: 'vertritt',
#  713: 'wirtschaftsfeindliche',
#  714: 'juan',
#  715: 'drosseln',
#  716: 'auswahlverfahren',
#  717: 'lauft',
#  718: 'beharrlich',
#  719: 'reproduktiven',
#  720: 'nachzueifern',
#  721: 'konfliktvermeidung',
#  722: 'umso',
#  723: 'immunitat',
#  724: 'einseitiger',
#  725: 'unangenehme',
#  726: 'kandidat',
#  727: 'baverez',
#  728: 'ungeheuer',
#  729: 'somit',
#  730: 'zugestandnis',
#  731: 'missverstandnissen',
#  732: 'produktivitatswachstum',
#  733: 'popularitat',
#  734: 'iaeo',
#  735: 'verschmutzt',
#  736: 'einzelhandelssektor',
#  737: 'hirse',
#  738: 'wahnsinn',
#  739: 'physisch',
#  740: 'better',
#  741: 'nachweisen',
#  742: 'bestands',
#  743: 'hayek',
#  744: 'einbeziehen',
#  745: 'hausermarkte',
#  746: 'sparkrise',
#  747: 'kurden',
#  748: 'alkoholabhangig',
#  749: 'gazas',
#  750: 'beispiellose',
#  751: 'weigerte',
#  752: 'ausgestorbene',
#  753: 'erlassen',
#  754: 'anstreben',
#  755: 'weltweiten',
#  756: 'schifffahrt',
#  757: 'einreisevisum',
#  758: 'widmet',
#  759: 'marktwirtschaft',
#  760: 'gefangnis',
#  761: 'geandert',
#  762: 'faszinierende',
#  763: 'turbulenteren',
#  764: 'generation',
#  765: 'pflege',
#  766: 'jobwunder',
#  767: 'anleihebewertung',
#  768: 'sparsamkeit',
#  769: 'patronage',
#  770: 'umgehend',
#  771: 'flutwelle',
#  772: 'entgegen',
#  773: 'putsch',
#  774: 'einnahmequelle',
#  775: 'gegebenheiten',
#  776: 'begriff',
#  777: 'motivation',
#  778: 'sakulare',
#  779: 'gegenoffensive',
#  780: 'berucksichtigen',
#  781: 'ethische',
#  782: 'verdeutlicht',
#  783: 'dadurch',
#  784: 'ubertragbaren',
#  785: 'maradona',
#  786: 'singularitat',
#  787: 'stagniert',
#  788: 'kriegslustig',
#  789: 'menschenunwurdig',
#  790: 'aufzahlen',
#  791: 'sonderbar',
#  792: 'verbrecher',
#  793: 'nachfragesteuerung',
#  794: 'liberale',
#  795: 'philosophenkonige',
#  796: 'boxer',
#  797: 'hinterlasst',
#  798: 'zusammensto',
#  799: 'alleinigen',
#  800: 'ernsthaftes',
#  801: 'mobilisierung',
#  802: 'sunden',
#  803: 'hebraisch',
#  804: 'altern',
#  805: 'duster',
#  806: 'krisenvermeidung',
#  807: 'indianer',
#  808: 'prinzips',
#  809: 'den',
#  810: 'beschreiten',
#  811: 'regelbasierter',
#  812: 'fallenden',
#  813: 'praktizierende',
#  814: 'besonders',
#  815: 'tiefgreifendere',
#  816: 'wankelmutige',
#  817: 'absurdes',
#  818: 'verkehrsstaus',
#  819: 'ausgebildete',
#  820: 'hussein',
#  821: 'fukudas',
#  822: 'spezialeinheiten',
#  823: 'anleihen',
#  824: 'angebrachter',
#  825: 'weltmeinung',
#  826: 'vergangenheitsbewaltigung',
#  827: 'ownership',
#  828: 'federal',
#  829: 'sudafrikas',
#  830: 'voraussicht',
#  831: 'wirksam',
#  832: 'gap',
#  833: 'erkenntnisse',
#  834: 'olgesellschaft',
#  835: 'offensichtlichen',
#  836: 'vielversprechendsten',
#  837: 'worin',
#  838: 'fluchtlings',
#  839: 'herausforderer',
#  840: 'fruhling',
#  841: 'bonuszahlungen',
#  842: 'bestmoglichen',
#  843: 'polio',
#  844: 'bestreiten',
#  845: 'bakiyew',
#  846: 'mensch',
#  847: 'gegenuber',
#  848: 'seuchen',
#  849: 'fuhrungsriege',
#  850: 'katastrophal',
#  851: 'rivalen',
#  852: 'solarzellen',
#  853: 'operation',
#  854: 'erderwarmung',
#  855: 'dezentralisierung',
#  856: 'erscheinen',
#  857: 'pokerspieler',
#  858: 'aufzuziehen',
#  859: 'haushaltsanpassung',
#  860: 'dilettant',
#  861: 'stabilitatsfonds',
#  862: 'hinsicht',
#  863: 'sheikh',
#  864: 'belastbarer',
#  865: 'zuruckgedreht',
#  866: 'maritimen',
#  867: 'seele',
#  868: 'rucktritt',
#  869: 'importzoll',
#  870: 'lukaschenko',
#  871: 'loste',
#  872: 'bereitschaft',
#  873: 'einzuwenden',
#  874: 'verengte',
#  875: 'pravention',
#  876: 'umgang',
#  877: 'weiten',
#  878: 'deja',
#  879: 'nuchterne',
#  880: 'scharlatane',
#  881: 'kakophonie',
#  882: 'berater',
#  883: 'bestimmter',
#  884: 'gambit',
#  885: 'medienbosse',
#  886: 'sd',
#  887: 'parteibosse',
#  888: 'welt',
#  889: 'datensequenzierung',
#  890: 'sparpolitik',
#  891: 'naturliches',
#  892: 'gesicht',
#  893: 'gehorte',
#  894: 'nostalgischer',
#  895: 'burgertugenden',
#  896: 'riskanten',
#  897: 'board',
#  898: 'annans',
#  899: 'referendum',
#  900: 'blutleeres',
#  901: 'verstoffwechseln',
#  902: 'hervorgetan',
#  903: 'wachstumsmarkte',
#  904: 'caroline',
#  905: 'machtprojektion',
#  906: 'geiselhaft',
#  907: 'verlockung',
#  908: 'demokraten',
#  909: 'von',
#  910: 'interessiert',
#  911: 'mazenatentum',
#  912: 'angeprangert',
#  913: 'verkorpert',
#  914: 'post',
#  915: 'kastenpolitik',
#  916: 'steuerbehorden',
#  917: 'verlagerung',
#  918: 'entschiedenste',
#  919: 'mindestreservesatz',
#  920: 'undurchschaubar',
#  921: 'dienstleistungen',
#  922: 'titel',
#  923: 'ambitioniert',
#  924: 'irrtum',
#  925: 'finanziell',
#  926: 'trab',
#  927: 'usa',
#  928: 'eierproduktion',
#  929: 'marchen',
#  930: 'tauziehen',
#  931: 'vorgebrachte',
#  932: 'verlangerung',
#  933: 'idomeneo',
#  934: 'widmeten',
#  935: 'nichtsdestoweniger',
#  936: 'wachstumspfad',
#  937: 'gleichstellungspolitik',
#  938: 'hochst',
#  939: 'backen',
#  940: 'palastinensergebieten',
#  941: 'kellner',
#  942: 'schuldenpanik',
#  943: 'vampirwitze',
#  944: 'bevormundende',
#  945: 'verfugbar',
#  946: 'terroranschlage',
#  947: 'henry',
#  948: 'befahigung',
#  949: 'welches',
#  950: 'daran',
#  951: 'bezeichnen',
#  952: 'kommen',
#  953: 'nacheiferung',
#  954: 'tendenz',
#  955: 'erhebliche',
#  956: 'wachhunde',
#  957: 'einsteins',
#  958: 'russlandpolitik',
#  959: 'gfci',
#  960: 'nuklearer',
#  961: 'unubersehbar',
#  962: 'griechischen',
#  963: 'wiederaufzubauen',
#  964: 'wasserbedarf',
#  965: 'unwiderruflicher',
#  966: 'bewerteter',
#  967: 'union',
#  968: 'jetzigen',
#  969: 'vollstandige',
#  970: 'exporte',
#  971: 'algerien',
#  972: 'phantomfriedensprozess',
#  973: 'sudlich',
#  974: 'klimamodelle',
#  975: 'signalisierten',
#  976: 'vorwiegend',
#  977: 'herumgefuhrt',
#  978: 'kehrten',
#  979: 'analogien',
#  980: 'cares',
#  981: 'fischereipolitik',
#  982: 'griffen',
#  983: 'pechvogel',
#  984: 'gewebebiopsie',
#  985: 'dennoch',
#  986: 'pferd',
#  987: 'politiker',
#  988: 'streben',
#  989: 'richte',
#  990: 'marktvertrauen',
#  991: 'ihre',
#  992: 'hochsten',
#  993: 'saakaschwili',
#  994: 'geo',
#  995: 'anreizes',
#  996: 'basis',
#  997: 'beispielsweise',
#  998: 'beschaftigung',
#  999: 'azam',
#  ...}

# %%
# Now we create the word embedding matrix randomly
WORD_DIM = 300

# Initialize randomly the word embedding matrix
word_embeddings = {'en': np.random.rand(len(word2idx['en']), WORD_DIM),
                   'de': np.random.rand(len(word2idx['de']), WORD_DIM)}

# Set the values to 0 for padding
word_embeddings['en'][word2idx['en']['_PAD_']] = np.zeros(WORD_DIM)
word_embeddings['de'][word2idx['de']['_PAD_']] = np.zeros(WORD_DIM)

# %%
print(f'shape en: {word_embeddings["en"].shape}')
print(f'shape de: {word_embeddings["de"].shape}')
# Out:
# shape en: (11476, 300)
# shape de: (16709, 300)

# %% [markdown]
# # Process the data.
#
# Now, we can add the word embedding indeces to our data to be fed to the model.

# %% [markdown]
# Let's use the attribute `word_idx` for all samples. In case a word is unknown, we will simply replace it with the work "_UNK_".

# %%
# We add the word indeces to all data splits
for split_data in [train_data.data, val_data.data, test_data.data]:
	for lang in ['en', 'de']:
		for sample in split_data:
			sample['{}_word_idx'.format(lang)] = []
			for token in sample['{}_text'.format(lang)].split():
				# If a word is not in our vocabulary, we put the UNK token instead
				sample['{}_word_idx'.format(lang)].append(word2idx[lang][token] if token in word2idx[lang] else word2idx[lang]['_UNK_'])

# %%
train_data[0], train_data.data[0]
# Out:
# ({'idx': 0,
#   'en_word_idx': tensor([ 4295, 10301,  1737,  6025,  9059,   409,  7890,  3787,  3261,  2522,
#            2604,  9974]),
#   'de_word_idx': tensor([13731, 12846, 15173, 13388,  4209,  1000, 14866,  2285, 14963,  2725,
#           14474])},
#  {'idx': 32674,
#   'en_text': 'if greece still had its own currency everything would be easier .',
#   'de_text': 'wenn griechenland noch seine eigene wahrung hatte ware alles einfacher .',
#   'en_word_idx': [4295,
#    10301,
#    1737,
#    6025,
#    9059,
#    409,
#    7890,
#    3787,
#    3261,
#    2522,
#    2604,
#    9974],
#   'de_word_idx': [13731,
#    12846,
#    15173,
#    13388,
#    4209,
#    1000,
#    14866,
#    2285,
#    14963,
#    2725,
#    14474]})

# %%
for lang in ['en', 'de']:
	for split_data in [train_data.data, val_data.data, test_data.data]:
		for sample in split_data:

			# Add _SOS_ and _EOS_ tokens!
			sample['{}_word_idx'.format(lang)] = [word2idx[lang]['_SOS_']] + sample['{}_word_idx'.format(lang)] + [word2idx[lang]['_EOS_']]

			# Pad
			while len(sample['{}_word_idx'.format(lang)]) < (MAX_WORDS + 3): # + 2 because of SOS and EOS
				sample['{}_word_idx'.format(lang)].append(word2idx[lang]['_PAD_'])

			# Sanity check
			assert len(sample['{}_word_idx'.format(lang)]) == (MAX_WORDS + 3)

# %%
train_data[5]
# Out:
# {'idx': 5,
#  'en_word_idx': tensor([    2,  9198,  1916,  5843, 10068,  4549,  5834,   255,  9974,     3,
#              0,     0,     0,     0,     0]),
#  'de_word_idx': tensor([    2, 14449, 16207,  4382,  8279,  5848,  5025,  1523, 14968, 14474,
#              3,     0,     0,     0,     0])}

# %% [markdown]
# # Modeling

# %%
class TranslationModel(nn.Module):
    def __init__(self, dropout, hidden_dim, words_num_src, words_num_des, word_dim):
        super(TranslationModel, self).__init__()

        # ENCODER
        self.src_word_embedding = nn.Embedding(num_embeddings=words_num_src, embedding_dim=word_dim)
        self.encoder = nn.GRU(input_size=word_dim,
                               hidden_size=hidden_dim,
                               num_layers=2, # Let's add an extra-layer
                               batch_first=True,
                               dropout=0, # No dropout; it is complicated for RNNs. Do you have an intuition why?
                               bidirectional=True) # Let's assume bi-directional

        # DECODER
        self.des_word_embedding = nn.Embedding(num_embeddings=words_num_des, embedding_dim=word_dim)
        self.decoder = nn.GRU(input_size=word_dim,
                               hidden_size=hidden_dim,
                               num_layers=1, # Here we keep it simple
                               batch_first=True,
                               dropout=0, # No dropout; it is complicated for RNNs. Do you have an intuition why?
                               bidirectional=False) # ATTENTION: we cannot have bidirectionality here!
        # The last layer to compute the probabilities for the output classes
        self.final_layer = nn.Linear(in_features=hidden_dim, out_features=words_num_des)

        # BONUS: How would you implement the attention component?

        self.dropout = nn.Dropout(dropout)
        self.activation = nn.Tanh()


    def forward(self, x_src, len_src, x_des, len_des, last_hidden=None):
        if last_hidden is None: # It means we have already encoded the input sentence and we are generated the output. This is a trick to not recompute at each decoding step the latent representation of the input sentence.
          ################
          # ENCODING PART#
          ################

          x_src = self.src_word_embedding(x_src)
          x_src = self.dropout(x_src)

          # PyTorch (and other frameworks) are using CuDNN for efficient neural networks.
          # For some reason, for LSTM, GRU, and RNN, the input sequences MUST be sorted by decreasing length
          # Therefore, we will do it manually before feeding the network AND also after in order to have the hidden vectors in the right order

          # 1. We sort the batch (and keep the sorting index) according to their sequencelength in decreasing order
          sorted_lengths, sorted_order = len_src.sort(0, descending=True)
          sorted_input = x_src[sorted_order] # Here we rearrange the batch
          _, invert_order = sorted_order.sort(0, descending=False) # We store the indeces of the sorting

          # 2. Because all sequences DO NOT have the same length, we might not want to waste GPU resources on useless computation.
          # For example:
          # a) I     am       Diego PAD  PAD
          # b) Ciao  ragazzi  PAD   PAD  PAD
          # c) We    are      doing deep learning
          #
          # Only c) needs to process the full sequence. In a) and b), only 3 and 2 steps are needed.
          # pack_padded_sequence will exactly help us and not compute 15 "operations" but only 10 in total. Here we save already ~33% of the GPU!
          prepared_input = nn.utils.rnn.pack_padded_sequence(sorted_input, sorted_lengths.cpu(), batch_first=True, enforce_sorted=True)

          # If you check the documentation https://pytorch.org/docs/stable/generated/torch.nn.LSTM.html#torch.nn.LSTM
          # hidden and cell (useless) will be the final hidden/cell state (NbDirection xBxH)
          # whereas output contains the values of the hidden states for each time step (NbDirection xBxLxH)
          _, hidden = self.encoder(prepared_input)# Bidirectional*nblayers x B x H

          # We aggregate into one vector
          hidden = torch.sum(hidden, dim=0)

          # 3. We sort back the hidden vectors
          hidden = hidden.index_select(0, invert_order)
          hidden = self.dropout(self.activation(hidden))
          hidden = hidden.unsqueeze(0)

          # Hidden is now our latent representation of our input sentence!
        else:
          hidden = last_hidden

        #################
        # DECODING PART #
        #################

        # We will be using Teacher-Focring, meaning that we will provide to the model the previous REAL words as input.
        # Hence, we need to encode the output sequence as well.
        # At inference (as we will see later), we will generate the output text in an auto-regressive manner, where is word has been predicted.
        x_des = self.des_word_embedding(x_des)
        x_des = self.dropout(x_des)

        sorted_lengths, sorted_order = len_des.sort(0, descending=True)
        sorted_input = x_des[sorted_order] # Here we rearrange the batch
        _, invert_order = sorted_order.sort(0, descending=False) # We store the indeces of the sorting
        hidden = hidden[:, sorted_order] # Pay attention: we have also to sort it!

        prepared_input = nn.utils.rnn.pack_padded_sequence(sorted_input, sorted_lengths.cpu(), batch_first=True, enforce_sorted=True)
        # We will parallelize and predict ALL next tokens in once step.
        # The most important here is to provide the context to initialize the hidden states
        output, new_last_hidden = self.decoder(prepared_input, hidden)

        # We unpack the output and reorder all hidden states.
        output = nn.utils.rnn.pad_packed_sequence(output, batch_first=True, total_length=torch.max(len_des) if last_hidden is None else 1)[0] #BxLxH
        output = output.index_select(0, invert_order)

        new_last_hidden = new_last_hidden.index_select(1, invert_order)
        output = self.dropout(self.activation(output))

        # Compute the log probabilities. We do not compute the probabilities with Softmax because depending the loss function, we might require unnormalized or probabilities.
        # Worst case, we can always apply F.softmax(output, dim=-1) later.
        word_logits = self.final_layer(output)
        return word_logits, new_last_hidden

# %%
x_src = torch.tensor([[1,2,3,4,5,0], [10,20,30,40,0,0], [5,6,0,0,0,0]])
len_src = torch.sum(x_src != 0, dim=1)
x_des = x_src[:, 1:]
len_des = len_src - 1

# %%
x_src, len_src
# Out:
# (tensor([[ 1,  2,  3,  4,  5,  0],
#          [10, 20, 30, 40,  0,  0],
#          [ 5,  6,  0,  0,  0,  0]]),
#  tensor([5, 4, 2]))

# %%
x_des, len_des
# Out:
# (tensor([[ 2,  3,  4,  5,  0],
#          [20, 30, 40,  0,  0],
#          [ 6,  0,  0,  0,  0]]),
#  tensor([4, 3, 1]))

# %%
translator = TranslationModel(dropout=0.1, hidden_dim=24, words_num_src=50, words_num_des=50, word_dim=12)
logits, last_hidden = translator(x_src, len_src, x_des, len_des)
logits, logits.size(), last_hidden.size()
# Out:
# (tensor([[[ 7.0946e-02,  1.8270e-01,  1.1369e-01,  1.4958e-01,  2.8110e-02,
#             2.2634e-01,  1.2713e-02,  3.0825e-01, -4.8444e-01, -1.1362e-01,
#             2.5104e-01,  7.4229e-02,  1.6561e-01,  2.4883e-03, -6.1863e-02,
#             2.0518e-02, -1.0992e-01,  2.3432e-01,  9.7835e-02, -3.7266e-01,
#             4.8402e-02, -1.6725e-01,  1.2586e-02, -2.1086e-01,  1.7871e-01,
#             2.5846e-01,  1.1262e-01,  3.4478e-01,  1.1535e-01, -2.5898e-01,
#             3.5374e-01, -3.2672e-01, -6.3701e-02, -4.1694e-01, -4.3081e-02,
#             2.5746e-01,  6.6177e-02, -1.1578e-01,  1.1648e-01,  9.3252e-02,
#            -8.0353e-02, -2.0053e-02, -1.4071e-01,  7.1730e-02,  3.2159e-01,
#             3.0349e-02, -9.6051e-03,  2.5669e-03, -1.5729e-01,  8.7764e-02],
#           [ 1.2079e-01,  1.8161e-01,  1.1327e-02,  7.2552e-02, -1.2333e-01,
#             7.3084e-02, -6.4113e-02,  1.8542e-01, -5.3381e-01, -6.5512e-02,
#             2.9753e-01, -2.2139e-01,  8.1073e-02,  1.9807e-02, -1.1500e-01,
#             7.5817e-02,  1.8570e-02,  3.3639e-01,  3.1499e-02, -3.8413e-01,
#             8.1716e-02, -9.8259e-02,  9.0894e-02, -1.0847e-01,  2.3993e-01,
#             2.8357e-01,  6.7894e-02,  1.2657e-01,  1.6546e-01, -2.0499e-01,
#             2.9341e-01, -4.0326e-01, -1.1095e-02, -4.5913e-01, -4.5618e-02,
#             3.7386e-01, -1.1827e-01, -2.1302e-01,  1.1706e-01, -9.9587e-02,
#            -1.2214e-01, -1.0330e-01, -1.0153e-01, -8.3001e-02,  9.1859e-02,
#            -8.9937e-02, -9.0493e-02, -3.1760e-03,  5.4513e-02,  3.2684e-03],
#           [ 8.5139e-02, -9.2757e-02, -1.3574e-01, -9.2717e-02, -2.1384e-01,
#             2.4620e-01,  1.0724e-02,  2.6717e-01, -4.0654e-01, -1.3717e-01,
#             2.2219e-01, -1.1171e-01,  1.9297e-01, -1.1618e-01, -1.9205e-01,
#            -1.3240e-01, -1.4912e-01,  1.8280e-01,  2.6252e-02, -3.9069e-01,
#            -1.0653e-01, -1.2963e-01,  3.8054e-02, -1.2788e-01,  1.1888e-01,
#             2.7599e-01,  4.7441e-02,  2.2017e-01,  1.5755e-01, -2.5611e-01,
#             3.8088e-01, -2.4514e-01, -1.2789e-01, -4.1171e-01,  6.3937e-02,
#             2.8985e-01,  8.5102e-03, -5.5367e-02, -3.4259e-02,  5.3116e-02,
#            -1.1039e-01, -1.3631e-01, -2.0240e-01, -3.1574e-01,  1.5180e-01,
#            -6.9517e-02,  4.0376e-02, -2.1022e-01,  9.6005e-02,  3.4342e-02],
#           [-6.4714e-02, -4.0396e-02, -1.4825e-02,  6.0531e-02, -1.2896e-01,
#             1.2338e-01, -1.8788e-01,  2.4953e-01, -4.9433e-01, -2.8476e-02,
#             4.8254e-01, -1.0956e-01, -7.7663e-02,  1.6983e-01, -2.8504e-01,
#            -2.1431e-01, -5.2193e-02,  3.5644e-01, -7.2896e-02, -4.9436e-01,
#             1.1863e-01, -1.5239e-01, -6.8656e-02, -2.9707e-01,  6.4163e-02,
#             2.5364e-01,  9.5581e-02,  1.8787e-01,  2.2674e-01, -3.5034e-01,
#             3.3976e-01, -2.5398e-01, -9.1514e-02, -4.6657e-01, -1.3647e-02,
#             3.1073e-01,  1.3183e-02, -2.7138e-01,  1.5676e-01, -2.0938e-01,
#            -1.5051e-01, -2.4932e-01,  1.1958e-02,  6.0060e-02,  1.0640e-01,
#             1.3263e-01, -2.1650e-01, -6.2397e-03,  9.1600e-02, -2.3564e-01]],
#
#          [[ 6.4269e-02, -1.2544e-01,  2.0088e-01, -4.0697e-01, -1.8482e-01,
#             4.4127e-01, -2.3744e-02,  6.1383e-04, -1.0617e-01, -2.0908e-01,
#            -1.1225e-01, -1.9205e-01,  7.3704e-02,  1.4163e-01, -1.6670e-01,
#            -3.9945e-01,  4.5343e-01, -1.2460e-01,  3.5035e-01, -1.9445e-01,
#             5.9931e-02, -3.3182e-01, -8.0561e-02, -3.5535e-01, -1.1977e-01,
#             3.5283e-01, -1.5366e-01,  3.4957e-01,  4.2592e-01, -1.7446e-01,
#            -1.1079e-03,  8.1226e-02, -2.2088e-01, -5.1344e-02,  1.6329e-01,
#             2.4694e-01,  6.7599e-02, -2.4795e-01, -5.7947e-02,  9.8668e-02,
#             6.6588e-02,  5.4248e-01, -2.0009e-01, -1.8668e-01,  3.6417e-01,
#            -1.1457e-01, -3.8963e-01, -2.0526e-01, -1.6234e-01,  1.0643e-01],
#           [-1.2916e-02, -3.4874e-02,  1.4688e-01, -1.5642e-01, -1.7640e-01,
#             3.3496e-01,  7.7680e-02,  1.4887e-01, -1.4412e-01, -8.3660e-02,
#             9.9858e-02, -2.3177e-01,  1.1413e-01,  2.5523e-01, -1.4405e-01,
#            -1.0682e-01,  3.1880e-01, -3.5702e-02,  2.5228e-01, -1.6222e-01,
#             6.3851e-02, -3.0165e-01, -5.6843e-02, -3.0678e-01, -6.6888e-05,
#             3.3372e-01, -1.7006e-01,  3.5980e-01,  3.4943e-01, -1.0068e-01,
#             2.0495e-01, -3.5140e-02,  3.0180e-02, -1.7903e-01,  5.7286e-02,
#             7.8396e-02,  1.8613e-01, -3.5201e-01, -1.5356e-02,  2.8324e-01,
#             7.4953e-02,  1.8670e-01, -1.7596e-01, -4.2753e-01,  3.5878e-01,
#            -3.8032e-02, -3.5320e-01, -1.0707e-03, -1.2222e-01,  3.0502e-01],
#           [-2.0769e-01,  3.5267e-01,  3.9036e-01,  1.4992e-01,  3.2810e-02,
#             2.8072e-01,  8.5176e-02,  1.3264e-01, -4.2267e-02, -2.9180e-01,
#             2.0820e-02, -1.2870e-01,  9.9080e-02,  2.0777e-01, -8.7836e-02,
#             8.8214e-02,  2.5509e-01, -1.4130e-01,  3.3382e-01, -1.3590e-01,
#             8.9777e-02, -1.3135e-01, -5.5792e-03, -2.2185e-01, -7.5571e-02,
#             4.0291e-01, -2.4690e-01,  2.0911e-01,  2.1529e-01, -7.3492e-02,
#            -1.9583e-01, -2.0510e-02,  8.9237e-02, -3.8949e-02, -1.2922e-01,
#             1.1494e-01,  1.6943e-01, -1.3456e-01,  1.6134e-01,  3.4680e-01,
#             2.4387e-02,  5.0232e-01, -6.6267e-02,  4.9690e-03,  4.2546e-01,
#            -2.1173e-02, -4.8777e-01,  1.5768e-02, -5.4133e-01,  3.1664e-01],
#           [-1.6207e-01,  1.2757e-01,  1.7340e-01, -1.3929e-02,  1.1925e-01,
#             1.0109e-01,  8.1222e-02,  2.5605e-02, -1.3344e-01, -1.8134e-01,
#             8.1748e-02, -1.3827e-01,  1.5731e-01,  4.2338e-02, -1.0334e-01,
#            -8.5923e-02,  4.9805e-02, -7.6571e-03,  1.7871e-01, -7.7593e-02,
#            -1.2033e-01, -1.8655e-01,  3.8166e-02, -1.5217e-01, -2.0698e-02,
#             2.0067e-01, -8.9939e-02,  1.8065e-01,  1.2424e-01, -1.2512e-01,
#             1.0811e-01, -8.0742e-02,  1.1005e-01, -1.1927e-01,  5.3920e-02,
#             1.1481e-01,  1.4995e-01, -7.5919e-02,  1.2013e-01,  1.4607e-01,
#            -5.1430e-02,  1.4254e-01, -4.3356e-02, -1.1627e-01,  7.1519e-02,
#             5.7250e-02, -1.8544e-01, -8.4247e-02, -5.0636e-02,  1.3428e-01]],
#
#          [[ 6.5545e-03, -3.1838e-02, -1.4366e-01, -3.4532e-01, -1.8514e-01,
#             8.1608e-02,  2.1387e-01,  1.1987e-03, -3.8697e-01, -1.0884e-01,
#             2.0363e-01, -2.7074e-01,  2.5630e-01, -6.1665e-02, -1.0720e-01,
#            -3.5359e-02, -4.5950e-02, -1.4293e-02,  1.9294e-01, -2.4904e-01,
#            -7.6542e-02, -2.5569e-01,  1.6524e-01,  6.1782e-02,  4.3056e-02,
#             3.4461e-01,  5.0617e-02,  1.2791e-01,  3.4441e-01, -2.6874e-01,
#             2.2767e-01, -3.2230e-01, -5.8984e-02, -5.4056e-02,  3.2613e-02,
#             2.4174e-01, -2.1837e-02, -6.4824e-03, -2.5712e-01,  1.7411e-01,
#            -2.4925e-01, -9.4115e-02, -1.6564e-01, -6.2585e-01, -1.4978e-01,
#            -1.9672e-01, -1.6370e-01, -3.1472e-01,  1.5617e-01,  3.8029e-01],
#           [-1.6207e-01,  1.2757e-01,  1.7340e-01, -1.3929e-02,  1.1925e-01,
#             1.0109e-01,  8.1222e-02,  2.5605e-02, -1.3344e-01, -1.8134e-01,
#             8.1748e-02, -1.3827e-01,  1.5731e-01,  4.2338e-02, -1.0334e-01,
#            -8.5923e-02,  4.9805e-02, -7.6571e-03,  1.7871e-01, -7.7593e-02,
#            -1.2033e-01, -1.8655e-01,  3.8166e-02, -1.5217e-01, -2.0698e-02,
#             2.0067e-01, -8.9939e-02,  1.8065e-01,  1.2424e-01, -1.2512e-01,
#             1.0811e-01, -8.0742e-02,  1.1005e-01, -1.1927e-01,  5.3920e-02,
#             1.1481e-01,  1.4995e-01, -7.5919e-02,  1.2013e-01,  1.4607e-01,
#            -5.1430e-02,  1.4254e-01, -4.3356e-02, -1.1627e-01,  7.1519e-02,
#             5.7250e-02, -1.8544e-01, -8.4247e-02, -5.0636e-02,  1.3428e-01],
#           [-1.6207e-01,  1.2757e-01,  1.7340e-01, -1.3929e-02,  1.1925e-01,
#             1.0109e-01,  8.1222e-02,  2.5605e-02, -1.3344e-01, -1.8134e-01,
#             8.1748e-02, -1.3827e-01,  1.5731e-01,  4.2338e-02, -1.0334e-01,
#            -8.5923e-02,  4.9805e-02, -7.6571e-03,  1.7871e-01, -7.7593e-02,
#            -1.2033e-01, -1.8655e-01,  3.8166e-02, -1.5217e-01, -2.0698e-02,
#             2.0067e-01, -8.9939e-02,  1.8065e-01,  1.2424e-01, -1.2512e-01,
#             1.0811e-01, -8.0742e-02,  1.1005e-01, -1.1927e-01,  5.3920e-02,
#             1.1481e-01,  1.4995e-01, -7.5919e-02,  1.2013e-01,  1.4607e-01,
#            -5.1430e-02,  1.4254e-01, -4.3356e-02, -1.1627e-01,  7.1519e-02,
#             5.7250e-02, -1.8544e-01, -8.4247e-02, -5.0636e-02,  1.3428e-01],
#           [-1.6207e-01,  1.2757e-01,  1.7340e-01, -1.3929e-02,  1.1925e-01,
#             1.0109e-01,  8.1222e-02,  2.5605e-02, -1.3344e-01, -1.8134e-01,
#             8.1748e-02, -1.3827e-01,  1.5731e-01,  4.2338e-02, -1.0334e-01,
#            -8.5923e-02,  4.9805e-02, -7.6571e-03,  1.7871e-01, -7.7593e-02,
#            -1.2033e-01, -1.8655e-01,  3.8166e-02, -1.5217e-01, -2.0698e-02,
#             2.0067e-01, -8.9939e-02,  1.8065e-01,  1.2424e-01, -1.2512e-01,
#             1.0811e-01, -8.0742e-02,  1.1005e-01, -1.1927e-01,  5.3920e-02,
#             1.1481e-01,  1.4995e-01, -7.5919e-02,  1.2013e-01,  1.4607e-01,
#            -5.1430e-02,  1.4254e-01, -4.3356e-02, -1.1627e-01,  7.1519e-02,
#             5.7250e-02, -1.8544e-01, -8.4247e-02, -5.0636e-02,  1.3428e-01]]],
#         grad_fn=<ViewBackward0>),
#  torch.Size([3, 4, 50]),
#  torch.Size([1, 3, 24]))

# %% [markdown]
# # Putting all together
#
# We now have the model, the data, and the loss function. We are ready to implement the training loop.

# %%
BATCH_SIZE = 128
SRC = 'en'
DES = 'de'

# We initialize our model
model = TranslationModel(dropout=0.1,
                         hidden_dim=128,
                         words_num_src=len(word2idx[SRC]),
                         words_num_des=len(word2idx[DES]),
                         word_dim=WORD_DIM)

# Copy the word embedding matrix
model.src_word_embedding.weight.data = torch.from_numpy(word_embeddings[SRC]).float()
model.src_word_embedding.weight.requires_grad = True

# Copy the word embedding matrix
model.des_word_embedding.weight.data = torch.from_numpy(word_embeddings[DES]).float()
model.des_word_embedding.weight.requires_grad = True

# %%
# We initialize our optimizer to update the weights of the model
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=0)

# %%
# We can load our dataset using a dataloader
train_loader = DataLoader(
        train_data,
        batch_size=BATCH_SIZE,
        shuffle=True, # Pay attention that we can shuffle the samples for training
        num_workers=0, # And specify how many working we want. 0/1 = 1
        drop_last=False) # Finally, it is possible to drop the last batch if its size is smaller than args.batch_size. In some applications, it is easier to ignore it instead of handling it.

val_loader = DataLoader(
        val_data,
        batch_size=BATCH_SIZE,
        shuffle=False, # Pay attention here that the data is not shuffled.
        num_workers=0,
        drop_last=False)

test_loader = DataLoader(
        test_data,
        batch_size=BATCH_SIZE,
        shuffle=False, # Pay attention here that the data is not shuffled.
        num_workers=0,
        drop_last=False)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cpu')

# %%
torch.cuda.is_available()
# Out:
# False

# %%
torch.cuda.device_count()
# Out:
# 0

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [125], line 1
# ----> 1 nvidia-smi
#
# NameError: name 'nvidia' is not defined

# %%
# Move the model to the device (CPU or GPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# Initialize the loss function
criterion = nn.CrossEntropyLoss(reduction='mean', ignore_index=0)

best_epoch = 0
best_val_so_far = float('inf')
test_perf = 0


# TRAINING LOOP
for epoch in range(50):
	print('------------------------------------------------------------------------')
	print('Epoch: {}'.format(epoch))

	# TRAIN
	# We set the model in train mode. It will store information to compute the gradients
	# Also, the implementation of dropout, batchnorm, etc is different at training and inference time.
	model.train()

	train_losses = []
	# Pay attention how the data loading become easiers!
	for idx, batch in tqdm.tqdm(enumerate(train_loader), desc='Training'):
		# Prepare data
		x_src = batch['{}_word_idx'.format(SRC)]
		len_src = torch.sum(x_src != 0, dim=1)
		x_des = batch['{}_word_idx'.format(DES)]
		len_des = torch.sum(x_des != 0, dim=1)

		# Move to GPU
		x_src = x_src.to(device)
		len_src = len_src.to(device)
		x_des = x_des.to(device)
		len_des = len_des.to(device)

		# Compute the model output and the loss
		y_logits, last_hidden = model(x_src, len_src, x_des, len_des)
		y_preds = y_logits
		y_gold = x_des[:, 1:y_preds.size(1)+1].contiguous()

		# We have to "flatten" the predictions because CE only handle tensors like BxC and B
		# print(y_preds.size(0)*y_preds.size(1),-1)
		# print(len(y_gold.view(-1)))
		loss = criterion(y_preds.view(y_preds.size(0)*y_preds.size(1), -1), y_gold.view(-1))
		ppl = math.exp(loss)

		# Update model parameters
		optimizer.zero_grad() # This is very important! By default, gradients are cumulated in tensors.
		loss.backward() # Now that gradients have been empties, we compute the new ones using the loss.
		clip_grad_norm_(model.parameters(), 3.0) # PAY ATTENTION: Protection against gradient exploding
		optimizer.step() # We do gradient update with our optimization function (i.e., the weights of the model are updated).

		train_losses.append(loss.item())

	# VAL + TEST
	val_test_losses = {'val': [], 'test': []}
	val_test_ppl = {'val': [], 'test': []}

	# Unlike before, we set the model in eval mode to compute correctly dropout, batchnorm etc
	model.eval()

	# We do not store information relative to gradients as we do not update the model.
	# That's the reason why inference requires less memory and is faster.
	with torch.no_grad():
		for split_data, data in [('val', val_loader), ('test', test_loader)]:
			# Pay attention how the data loading become easiers!
			for idx, batch in tqdm.tqdm(enumerate(data), desc=split_data.capitalize()):
				# Prepare data
				x_src = batch['{}_word_idx'.format(SRC)]
				len_src = torch.sum(x_src != 0, dim=1)
				x_des = batch['{}_word_idx'.format(DES)]
				len_des = torch.sum(x_des != 0, dim=1)

				# Move to GPU
				x_src = x_src.to(device)
				len_src = len_src.to(device)
				x_des = x_des.to(device)
				len_des = len_des.to(device)

				# Compute the model output and the loss
				y_logits, last_hidden = model(x_src, len_src, x_des, len_des) #BxLxC (17)
				y_preds = y_logits
				y_gold = x_des[:, 1:y_preds.size(1)+1].contiguous()

				# We have to "flatten" the predictions because CE only handle tensors like BxC and B
				loss = criterion(y_preds.view(y_preds.size(0)*y_preds.size(1), -1), y_gold.view(-1))
				ppl = math.exp(loss)

				val_test_losses[split_data].append(loss.item())
				val_test_ppl[split_data].append(ppl)

	# Monitoring
	print('Train loss: {:.4f}'.format(np.mean(train_losses)))
	print('Val   loss: {:.4f}'.format(np.mean(val_test_losses['val'])))
	print('Test  loss: {:.4f}'.format(np.mean(val_test_losses['test'])))
	print()

	val_ppl = np.mean(val_test_ppl['val'])
	test_ppl = np.mean(val_test_ppl['test'])
	print('Val   PPL: {:.4f}'.format(val_ppl))
	print('Test  PPL: {:.4f}'.format(test_ppl))
	print()

	if val_ppl < best_val_so_far:
		best_val_so_far = val_ppl
		test_perf = test_ppl
		best_epoch = epoch
		torch.save(model.state_dict(), 'my_model.ckpt')

	print('Best Epoch: {}, best val PPL: {:.4f}, test PPL: {:.4f}'.format(best_epoch, best_val_so_far, test_perf))
	print()
	print()
# Out:
# ------------------------------------------------------------------------
# Epoch: 0
# Training: 118it [01:38,  1.20it/s]
# Val: 28it [00:07,  3.69it/s]
# Test: 28it [00:07,  3.71it/s]
# Train loss: 5.8176
# Val   loss: 6.0439
# Test  loss: 6.0292
#
# Val   PPL: 422.8143
# Test  PPL: 417.1273
#
# Best Epoch: 0, best val PPL: 422.8143, test PPL: 417.1273
#
#
# ------------------------------------------------------------------------
# Epoch: 1
# Training: 118it [01:38,  1.20it/s]
# Val: 28it [00:07,  3.71it/s]
# Test: 28it [00:07,  3.73it/s]
# Train loss: 5.6506
# Val   loss: 5.9607
# Test  loss: 5.9450
#
# Val   PPL: 389.1851
# Test  PPL: 383.5495
#
# Best Epoch: 1, best val PPL: 389.1851, test PPL: 383.5495
#
#
# ------------------------------------------------------------------------
# Epoch: 2
# Training: 118it [01:37,  1.21it/s]
# Val: 28it [00:07,  3.70it/s]
# Test: 28it [00:07,  3.73it/s]
# Train loss: 5.5017
# Val   loss: 5.9049
# Test  loss: 5.8883
#
# Val   PPL: 368.2311
# Test  PPL: 362.5582
#
# Best Epoch: 2, best val PPL: 368.2311, test PPL: 362.5582
#
#
# ------------------------------------------------------------------------
# Epoch: 3
# Training: 118it [01:37,  1.21it/s]
# Val: 28it [00:07,  3.71it/s]
# Test: 28it [00:07,  3.73it/s]
# Train loss: 5.3616
# Val   loss: 5.8302
# Test  loss: 5.8136
#
# Val   PPL: 341.8554
# Test  PPL: 336.4780
#
# Best Epoch: 3, best val PPL: 341.8554, test PPL: 336.4780
#
#
# ------------------------------------------------------------------------
# Epoch: 4
# Training: 118it [01:37,  1.21it/s]
# Val: 28it [00:07,  3.73it/s]
# Test: 28it [00:07,  3.74it/s]
# Train loss: 5.2246
# Val   loss: 5.7745
# Test  loss: 5.7582
#
# Val   PPL: 323.4972
# Test  PPL: 318.5616
#
# Best Epoch: 4, best val PPL: 323.4972, test PPL: 318.5616
#
#
# ------------------------------------------------------------------------
# Epoch: 5
# Training: 118it [01:37,  1.21it/s]
# Val: 28it [00:07,  3.73it/s]
# Test: 28it [00:07,  3.74it/s]
# Train loss: 5.0899
# Val   loss: 5.7402
# Test  loss: 5.7243
#
# Val   PPL: 312.7614
# Test  PPL: 308.0227
#
# Best Epoch: 5, best val PPL: 312.7614, test PPL: 308.0227
#
#
# ------------------------------------------------------------------------
# Epoch: 6
# Training: 118it [01:38,  1.20it/s]
# Val: 28it [00:07,  3.71it/s]
# Test: 28it [00:07,  3.73it/s]
# Train loss: 4.9665
# Val   loss: 5.7018
# Test  loss: 5.6878
#
# Val   PPL: 301.1329
# Test  PPL: 297.0633
#
# Best Epoch: 6, best val PPL: 301.1329, test PPL: 297.0633
#
#
# ------------------------------------------------------------------------
# Epoch: 7
# Training: 118it [01:38,  1.20it/s]
# Val: 28it [00:07,  3.71it/s]
# Test: 28it [00:07,  3.73it/s]
# Train loss: 4.8432
# Val   loss: 5.6806
# Test  loss: 5.6698
#
# Val   PPL: 294.9081
# Test  PPL: 291.8569
#
# Best Epoch: 7, best val PPL: 294.9081, test PPL: 291.8569
#
#
# ------------------------------------------------------------------------
# Epoch: 8
# Training: 118it [01:37,  1.21it/s]
# Val: 28it [00:07,  3.72it/s]
# Test: 28it [00:07,  3.74it/s]
# Train loss: 4.7265
# Val   loss: 5.6358
# Test  loss: 5.6235
#
# Val   PPL: 282.1391
# Test  PPL: 278.6223
#
# Best Epoch: 8, best val PPL: 282.1391, test PPL: 278.6223
#
#
# ------------------------------------------------------------------------
# Epoch: 9
# Training: 118it [01:37,  1.21it/s]
# Val: 28it [00:07,  3.71it/s]
# Test: 28it [00:07,  3.74it/s]
# Train loss: 4.6069
# Val   loss: 5.6272
# Test  loss: 5.6154
#
# Val   PPL: 279.8933
# Test  PPL: 276.5927
#
# Best Epoch: 9, best val PPL: 279.8933, test PPL: 276.5927
#
#
# ------------------------------------------------------------------------
# Epoch: 10
# Training: 118it [01:37,  1.21it/s]
# Val: 28it [00:07,  3.72it/s]
# Test: 28it [00:07,  3.74it/s]
# Train loss: 4.4965
# Val   loss: 5.5940
# Test  loss: 5.5807
#
# Val   PPL: 270.7343
# Test  PPL: 267.1560
#
# Best Epoch: 10, best val PPL: 270.7343, test PPL: 267.1560
#
#
# ------------------------------------------------------------------------
# Epoch: 11
# Training: 118it [01:37,  1.21it/s]
# Val: 28it [00:07,  3.73it/s]
# Test: 28it [00:07,  3.74it/s]
# Train loss: 4.3867
# Val   loss: 5.5892
# Test  loss: 5.5770
#
# Val   PPL: 269.6520
# Test  PPL: 266.2048
#
# Best Epoch: 11, best val PPL: 269.6520, test PPL: 266.2048
#
#
# ------------------------------------------------------------------------
# Epoch: 12
# Training: 118it [01:37,  1.21it/s]
# Val: 28it [00:07,  3.73it/s]
# Test: 28it [00:07,  3.74it/s]
# Train loss: 4.2837
# Val   loss: 5.5733
# Test  loss: 5.5542
#
# Val   PPL: 265.3843
# Test  PPL: 260.2485
#
# Best Epoch: 12, best val PPL: 265.3843, test PPL: 260.2485
#
#
# ------------------------------------------------------------------------
# Epoch: 13
# Training: 118it [01:37,  1.21it/s]
# Val: 28it [00:07,  3.73it/s]
# Test: 28it [00:07,  3.74it/s]
# Train loss: 4.1754
# Val   loss: 5.5722
# Test  loss: 5.5567
#
# Val   PPL: 265.2102
# Test  PPL: 261.0083
#
# Best Epoch: 13, best val PPL: 265.2102, test PPL: 261.0083
#
#
# ------------------------------------------------------------------------
# Epoch: 14
# Training: 118it [01:37,  1.21it/s]
# Val: 28it [00:07,  3.73it/s]
# Test: 28it [00:07,  3.73it/s]
# Train loss: 4.0764
# Val   loss: 5.5744
# Test  loss: 5.5562
#
# Val   PPL: 265.8882
# Test  PPL: 260.9218
#
# Best Epoch: 13, best val PPL: 265.2102, test PPL: 261.0083
#
#
# ------------------------------------------------------------------------
# Epoch: 15
# Training: 118it [01:37,  1.21it/s]
# Val: 28it [00:07,  3.72it/s]
# Test: 28it [00:07,  3.74it/s]
# Train loss: 3.9795
# Val   loss: 5.5786
# Test  loss: 5.5614
#
# Val   PPL: 267.0338
# Test  PPL: 262.3245
#
# Best Epoch: 13, best val PPL: 265.2102, test PPL: 261.0083
#
#
# ------------------------------------------------------------------------
# Epoch: 16
# Training: 118it [01:37,  1.21it/s]
# Val: 28it [00:07,  3.70it/s]
# Test: 28it [00:07,  3.73it/s]
# Train loss: 3.8871
# Val   loss: 5.5858
# Test  loss: 5.5673
#
# Val   PPL: 269.1302
# Test  PPL: 263.9802
#
# Best Epoch: 13, best val PPL: 265.2102, test PPL: 261.0083
#
#
# ------------------------------------------------------------------------
# Epoch: 17
# Training: 118it [01:37,  1.21it/s]
# Val: 28it [00:07,  3.72it/s]
# Test: 28it [00:07,  3.73it/s]
# Train loss: 3.7936
# Val   loss: 5.5942
# Test  loss: 5.5760
#
# Val   PPL: 271.4350
# Test  PPL: 266.4139
#
# Best Epoch: 13, best val PPL: 265.2102, test PPL: 261.0083
#
#
# ------------------------------------------------------------------------
# Epoch: 18
# Training: 118it [01:37,  1.21it/s]
# Val: 28it [00:07,  3.71it/s]
# Test: 28it [00:07,  3.73it/s]
# Train loss: 3.7033
# Val   loss: 5.5913
# Test  loss: 5.5741
#
# Val   PPL: 270.7180
# Test  PPL: 265.9378
#
# Best Epoch: 13, best val PPL: 265.2102, test PPL: 261.0083
#
#
# ------------------------------------------------------------------------
# Epoch: 19
# Training: 118it [01:37,  1.21it/s]
# Val: 28it [00:07,  3.72it/s]
# Test: 28it [00:07,  3.74it/s]
# Train loss: 3.6122
# Val   loss: 5.6163
# Test  loss: 5.5965
#
# Val   PPL: 277.6187
# Test  PPL: 272.0474
#
# Best Epoch: 13, best val PPL: 265.2102, test PPL: 261.0083
#
#
# ------------------------------------------------------------------------
# Epoch: 20
# Training: 118it [01:37,  1.21it/s]
# Val: 28it [00:07,  3.73it/s]
# Test: 28it [00:07,  3.74it/s]
# Train loss: 3.5294
# Val   loss: 5.6070
# Test  loss: 5.5891
#
# Val   PPL: 274.9734
# Test  PPL: 270.0844
#
# Best Epoch: 13, best val PPL: 265.2102, test PPL: 261.0083
#
#
# ------------------------------------------------------------------------
# Epoch: 21
# Training: 118it [01:37,  1.21it/s]
# Val: 28it [00:07,  3.73it/s]
# Test: 28it [00:07,  3.75it/s]
# Train loss: 3.4446
# Val   loss: 5.6208
# Test  loss: 5.6036
#
# Val   PPL: 279.0636
# Test  PPL: 274.1417
#
# Best Epoch: 13, best val PPL: 265.2102, test PPL: 261.0083
#
#
# ------------------------------------------------------------------------
# Epoch: 22
# Training: 118it [01:37,  1.21it/s]
# Val: 28it [00:07,  3.72it/s]
# Test: 28it [00:07,  3.74it/s]
# Train loss: 3.3663
# Val   loss: 5.6491
# Test  loss: 5.6311
#
# Val   PPL: 287.0578
# Test  PPL: 281.8088
#
# Best Epoch: 13, best val PPL: 265.2102, test PPL: 261.0083
#
#
# ------------------------------------------------------------------------
# Epoch: 23
# Training: 118it [01:37,  1.21it/s]
# Val: 28it [00:07,  3.72it/s]
# Test: 28it [00:07,  3.74it/s]
# Train loss: 3.2877
# Val   loss: 5.6639
# Test  loss: 5.6476
#
# Val   PPL: 291.3922
# Test  PPL: 286.4569
#
# Best Epoch: 13, best val PPL: 265.2102, test PPL: 261.0083
#
#
# ------------------------------------------------------------------------
# Epoch: 24
# Training: 118it [01:37,  1.21it/s]
# Val: 28it [00:07,  3.73it/s]
# Test: 28it [00:07,  3.74it/s]
# Train loss: 3.2089
# Val   loss: 5.6627
# Test  loss: 5.6448
#
# Val   PPL: 291.0402
# Test  PPL: 285.7776
#
# Best Epoch: 13, best val PPL: 265.2102, test PPL: 261.0083
#
#
# ------------------------------------------------------------------------
# Epoch: 25
# Training: 118it [01:37,  1.21it/s]
# Val: 28it [00:07,  3.73it/s]
# Test: 28it [00:07,  3.74it/s]
# Train loss: 3.1365
# Val   loss: 5.6916
# Test  loss: 5.6733
#
# Val   PPL: 299.8412
# Test  PPL: 294.1517
#
# Best Epoch: 13, best val PPL: 265.2102, test PPL: 261.0083
#
#
# ------------------------------------------------------------------------
# Epoch: 26
# Training: 118it [01:37,  1.21it/s]
# Val: 28it [00:07,  3.73it/s]
# Test: 28it [00:07,  3.74it/s]
# Train loss: 3.0627
# Val   loss: 5.7042
# Test  loss: 5.6797
#
# Val   PPL: 303.6842
# Test  PPL: 296.0785
#
# Best Epoch: 13, best val PPL: 265.2102, test PPL: 261.0083
#
#
# ------------------------------------------------------------------------
# Epoch: 27
# Training: 118it [01:37,  1.21it/s]
# Val: 28it [00:07,  3.73it/s]
# Test: 28it [00:07,  3.74it/s]
# Train loss: 2.9934
# Val   loss: 5.7173
# Test  loss: 5.6952
#
# Val   PPL: 307.6333
# Test  PPL: 300.7126
#
# Best Epoch: 13, best val PPL: 265.2102, test PPL: 261.0083
#
#
# ------------------------------------------------------------------------
# Epoch: 28
# Training: 118it [01:37,  1.21it/s]
# Val: 28it [00:07,  3.73it/s]
# Test: 28it [00:07,  3.74it/s]
# Train loss: 2.9260
# Val   loss: 5.7278
# Test  loss: 5.7090
#
# Val   PPL: 310.9538
# Test  PPL: 304.9565
#
# Best Epoch: 13, best val PPL: 265.2102, test PPL: 261.0083
#
#
# ------------------------------------------------------------------------
# Epoch: 29
# Training: 118it [01:37,  1.21it/s]
# Val: 28it [00:07,  3.74it/s]
# Test: 28it [00:07,  3.74it/s]
# Train loss: 2.8592
# Val   loss: 5.7474
# Test  loss: 5.7234
#
# Val   PPL: 317.2017
# Test  PPL: 309.3351
#
# Best Epoch: 13, best val PPL: 265.2102, test PPL: 261.0083
#
#
# ------------------------------------------------------------------------
# Epoch: 30
# Training: 118it [01:37,  1.21it/s]
# Val: 28it [00:07,  3.74it/s]
# Test: 28it [00:07,  3.74it/s]
# Train loss: 2.7963
# Val   loss: 5.7772
# Test  loss: 5.7516
#
# Val   PPL: 326.9684
# Test  PPL: 318.2896
#
# Best Epoch: 13, best val PPL: 265.2102, test PPL: 261.0083
#
#
# ------------------------------------------------------------------------
# Epoch: 31
# Training: 118it [01:37,  1.22it/s]
# Val: 28it [00:07,  3.74it/s]
# Test: 28it [00:07,  3.75it/s]
# Train loss: 2.7343
# Val   loss: 5.7942
# Test  loss: 5.7702
#
# Val   PPL: 332.6188
# Test  PPL: 324.3201
#
# Best Epoch: 13, best val PPL: 265.2102, test PPL: 261.0083
#
#
# ------------------------------------------------------------------------
# Epoch: 32
# Training: 118it [01:36,  1.22it/s]
# Val: 28it [00:07,  3.74it/s]
# Test: 28it [00:07,  3.75it/s]
# Train loss: 2.6776
# Val   loss: 5.8125
# Test  loss: 5.7858
#
# Val   PPL: 338.8097
# Test  PPL: 329.6742
#
# Best Epoch: 13, best val PPL: 265.2102, test PPL: 261.0083
#
#
# ------------------------------------------------------------------------
# Epoch: 33
# Training: 118it [01:36,  1.22it/s]
# Val: 28it [00:07,  3.74it/s]
# Test: 28it [00:07,  3.74it/s]
# Train loss: 2.6176
# Val   loss: 5.8401
# Test  loss: 5.8138
#
# Val   PPL: 348.6279
# Test  PPL: 339.0641
#
# Best Epoch: 13, best val PPL: 265.2102, test PPL: 261.0083
#
#
# ------------------------------------------------------------------------
# Epoch: 34
# Training: 118it [01:36,  1.22it/s]
# Val: 28it [00:07,  3.74it/s]
# Test: 28it [00:07,  3.75it/s]
# Train loss: 2.5654
# Val   loss: 5.8439
# Test  loss: 5.8190
#
# Val   PPL: 349.6409
# Test  PPL: 340.8665
#
# Best Epoch: 13, best val PPL: 265.2102, test PPL: 261.0083
#
#
# ------------------------------------------------------------------------
# Epoch: 35
# Training: 118it [01:36,  1.22it/s]
# Val: 28it [00:07,  3.74it/s]
# Test: 28it [00:07,  3.75it/s]
# Train loss: 2.5086
# Val   loss: 5.8673
# Test  loss: 5.8396
#
# Val   PPL: 358.0781
# Test  PPL: 347.9559
#
# Best Epoch: 13, best val PPL: 265.2102, test PPL: 261.0083
#
#
# ------------------------------------------------------------------------
# Epoch: 36
# Training: 118it [01:36,  1.22it/s]
# Val: 28it [00:07,  3.74it/s]
# Test: 28it [00:07,  3.75it/s]
# Train loss: 2.4568
# Val   loss: 5.8817
# Test  loss: 5.8528
#
# Val   PPL: 363.3548
# Test  PPL: 352.4819
#
# Best Epoch: 13, best val PPL: 265.2102, test PPL: 261.0083
#
#
# ------------------------------------------------------------------------
# Epoch: 37
# Training: 118it [01:36,  1.22it/s]
# Val: 28it [00:07,  3.74it/s]
# Test: 28it [00:07,  3.75it/s]
# Train loss: 2.4077
# Val   loss: 5.9043
# Test  loss: 5.8741
#
# Val   PPL: 371.5799
# Test  PPL: 360.1451
#
# Best Epoch: 13, best val PPL: 265.2102, test PPL: 261.0083
#
#
# ------------------------------------------------------------------------
# Epoch: 38
# Training: 118it [01:36,  1.22it/s]
# Val: 28it [00:07,  3.73it/s]
# Test: 28it [00:07,  3.75it/s]
# Train loss: 2.3619
# Val   loss: 5.9408
# Test  loss: 5.9103
#
# Val   PPL: 385.6082
# Test  PPL: 373.7955
#
# Best Epoch: 13, best val PPL: 265.2102, test PPL: 261.0083
#
#
# ------------------------------------------------------------------------
# Epoch: 39
# Training: 118it [02:41,  1.36s/it]
# Val: 28it [00:07,  3.70it/s]
# Test: 28it [00:07,  3.74it/s]
# Train loss: 2.3151
# Val   loss: 5.9411
# Test  loss: 5.9178
#
# Val   PPL: 385.9788
# Test  PPL: 376.4702
#
# Best Epoch: 13, best val PPL: 265.2102, test PPL: 261.0083
#
#
# ------------------------------------------------------------------------
# Epoch: 40
# Training: 118it [01:37,  1.21it/s]
# Val: 28it [00:07,  3.72it/s]
# Test: 28it [00:07,  3.73it/s]
# Train loss: 2.2695
# Val   loss: 5.9673
# Test  loss: 5.9388
#
# Val   PPL: 396.3046
# Test  PPL: 384.5687
#
# Best Epoch: 13, best val PPL: 265.2102, test PPL: 261.0083
#
#
# ------------------------------------------------------------------------
# Epoch: 41
# Training: 118it [01:37,  1.21it/s]
# Val: 28it [00:07,  3.73it/s]
# Test: 28it [00:07,  3.74it/s]
# Train loss: 2.2248
# Val   loss: 5.9917
# Test  loss: 5.9601
#
# Val   PPL: 406.1898
# Test  PPL: 392.9380
#
# Best Epoch: 13, best val PPL: 265.2102, test PPL: 261.0083
#
#
# ------------------------------------------------------------------------
# Epoch: 42
# Training: 118it [01:37,  1.21it/s]
# Val: 28it [00:07,  3.71it/s]
# Test: 28it [00:07,  3.73it/s]
# Train loss: 2.1836
# Val   loss: 6.0279
# Test  loss: 5.9985
#
# Val   PPL: 421.8728
# Test  PPL: 408.2022
#
# Best Epoch: 13, best val PPL: 265.2102, test PPL: 261.0083
#
#
# ------------------------------------------------------------------------
# Epoch: 43
# Training: 118it [01:36,  1.22it/s]
# Val: 28it [00:07,  3.75it/s]
# Test: 28it [00:07,  3.75it/s]
# Train loss: 2.1410
# Val   loss: 6.0268
# Test  loss: 5.9991
#
# Val   PPL: 421.2659
# Test  PPL: 408.5827
#
# Best Epoch: 13, best val PPL: 265.2102, test PPL: 261.0083
#
#
# ------------------------------------------------------------------------
# Epoch: 44
# Training: 118it [01:36,  1.22it/s]
# Val: 28it [00:07,  3.73it/s]
# Test: 28it [00:07,  3.75it/s]
# Train loss: 2.1000
# Val   loss: 6.0573
# Test  loss: 6.0231
#
# Val   PPL: 434.7237
# Test  PPL: 418.7194
#
# Best Epoch: 13, best val PPL: 265.2102, test PPL: 261.0083
#
#
# ------------------------------------------------------------------------
# Epoch: 45
# Training: 118it [01:36,  1.22it/s]
# Val: 28it [00:07,  3.73it/s]
# Test: 28it [00:07,  3.75it/s]
# Train loss: 2.0629
# Val   loss: 6.0595
# Test  loss: 6.0311
#
# Val   PPL: 435.0058
# Test  PPL: 422.1083
#
# Best Epoch: 13, best val PPL: 265.2102, test PPL: 261.0083
#
#
# ------------------------------------------------------------------------
# Epoch: 46
# Training: 118it [01:36,  1.22it/s]
# Val: 28it [00:07,  3.73it/s]
# Test: 28it [00:07,  3.75it/s]
# Train loss: 2.0211
# Val   loss: 6.0884
# Test  loss: 6.0606
#
# Val   PPL: 448.0156
# Test  PPL: 434.8251
#
# Best Epoch: 13, best val PPL: 265.2102, test PPL: 261.0083
#
#
# ------------------------------------------------------------------------
# Epoch: 47
# Training: 39it [00:33,  1.17it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [126], line 51
#      49 # Update model parameters
#      50 optimizer.zero_grad() # This is very important! By default, gradients are cumulated in tensors.
# ---> 51 loss.backward() # Now that gradients have been empties, we compute the new ones using the loss.
#      52 clip_grad_norm_(model.parameters(), 3.0) # PAY ATTENTION: Protection against gradient exploding
#      53 optimizer.step() # We do gradient update with our optimization function (i.e., the weights of the model are updated).
#
# File ~/PyProjects/CLT/venv3.8/lib/python3.8/site-packages/torch/_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     477 if has_torch_function_unary(self):
#     478     return handle_torch_function(
#     479         Tensor.backward,
#     480         (self,),
#    (...)
#     485         inputs=inputs,
#     486     )
# --> 487 torch.autograd.backward(
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#     489 )
#
# File ~/PyProjects/CLT/venv3.8/lib/python3.8/site-packages/torch/autograd/__init__.py:197, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     192     retain_graph = create_graph
#     194 # The reason we repeat same the comment below is that
#     195 # some Python versions print out the first line of a multi-line function
#     196 # calls in the traceback and some print out the last line
# --> 197 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     198     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     199     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
vocabulary = set()

for sample in data_train['translation']: # Pay attention we only use the training set!
	for token in sample['en']:
		vocabulary.add(token)
len(vocabulary)

# %%
vocabulary = set()

for sample in data_train['translation'][:1]:
	print(sample)
	for token in sample['de']:
		print(token)
		vocabulary.add(token)
len(vocabulary)

# %%
data_train['translation'][0]['en']

# %%
len(data_train['translation'])

# %%
type(data_train['translation'])

# %%
data_train['translation']

# %%
from torch.utils.data import Dataset, DataLoader
import torch

class TranslationDataset(Dataset):
    def __init__(self, data):
        self.data = data

    # We return the length of the dataset
    def __len__(self):
        return len(self.data)

    # We return the idx'th sample
    def __getitem__(self, idx):
        return {
            'idx': idx,
            'en_word_idx': torch.tensor(self.data[idx]['en_word_idx']).long(),
            'fr_word_idx': torch.tensor(self.data[idx]['fr_word_idx']).long(),
        }

# %%
train_data = TranslationDataset(data_train['translation'])

# %%
data_train
